# %% [markdown]
# # IMPORTING LIBS

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from pprint import pprint
import json 
browser = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Rax\.wdm\drivers\chromedriver\win32\101.0.4951.41]
# <ipython-input-1-e36d0de283a6>:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# # Creating links to each category makrocambodiaclick

# %%
webPath = 'https://www.makrocambodiaclick.com/en/'
categoryPath = 'https://www.makrocambodiaclick.com/en/category/'

r = requests.get(webPath)

# adding beautiful soup
soup = bs(r.content)

contents = soup.prettify()

info_box = soup.find_all(class_="PopularCategoriesCarousel__Text1line-sc-1hg143z-0 RbTcU")

# info_box

catName = [categoryPath+x.get_text().replace(" ", "") for x in info_box]

catName

# %% [markdown]
# # Creating function for crawling category page makrocambodiaclick

# %% [markdown]
# ## Sample of getting the product (sample code)

# %%
browser.get('https://www.makrocambodiaclick.com/en/category/Fish&Seafood?all=true')
time.sleep(5)
html = browser.page_source
soup_pagination = bs(html, 'html.parser')
pagination = soup.find_all(class_='pagination')
# print(week)
for i in pagination:
    print(i.text)

# %%
product_dictionary = {}
def get_makro_productName(url,product_type):
    pagination_list = []
    browser.get(url)
    time.sleep(5)
    html = browser.page_source
    soup = bs(html, 'html.parser')
    pagination = soup.find_all(class_='pagination')
    for i in pagination:
        pagination_list.append(i.text)
    if len(pagination_list) > 1:
        print('More than 1')
        for res in pagination_list:
            print(res)
            browser.get(url+'?page='+res+'&sorting=SORTING_LAST_UPDATE&all=true')
            time.sleep(20)
            html = browser.page_source
            soup_pagination = bs(html, 'html.parser')
            print(url+'?page='+res+'&sorting=SORTING_LAST_UPDATE&all=true')
            product_info =  soup_pagination.find_all(class_='ProductCard__CardProduct-sc-1lb6pe3-0 ktTHor')
            for each_product in product_info:
                product_name = each_product.find(class_='ProductCard__TitleMaxLines-sc-1lb6pe3-2 kAKAhd pt-2').text
                product_price_usd = each_product.find(class_='ProductCard__TextPrice-sc-1lb6pe3-1 jcvzXx m-0 mt-lg-1 font-16 color-red weight-bold d-flex align-items-end').text
                product_price_kh = each_product.find(class_='d-flex justify-content-between align-items-center').find('div',class_='m-0 mt-lg-1 font-11 d-flex align-items-end').text
                product_dictionary[product_name] = {'typeOf': product_type, 'infos': {'price_usd': product_price_usd, 'price_kh': product_price_kh}}
    else:
        browser.get(url+'?all=true')
        time.sleep(20)
        html = browser.page_source
        soup_pagination = bs(html, 'html.parser')
        product_info =  soup_pagination.find_all(class_='ProductCard__CardProduct-sc-1lb6pe3-0 ktTHor')
        for each_product in product_info:
            product_name = each_product.find(class_='ProductCard__TitleMaxLines-sc-1lb6pe3-2 kAKAhd pt-2').text
            product_price_usd = each_product.find(class_='ProductCard__TextPrice-sc-1lb6pe3-1 jcvzXx m-0 mt-lg-1 font-16 color-red weight-bold d-flex align-items-end').text
            product_price_kh = each_product.find(class_='d-flex justify-content-between align-items-center').find('div',class_='m-0 mt-lg-1 font-11 d-flex align-items-end').text
            product_dictionary[product_name] = {'typeOf': product_type, 'infos': {'price_usd': product_price_usd, 'price_kh': product_price_kh}}

# %% [markdown]
# # Calling all the items in each page to store in dictionary.

# %%
for product in catName:
    get_makro_productName(product,product.split('/')[5])

# %% [markdown]
# # Function taking value

# %% [markdown]
# ## Get single page scraping

# %%
get_makro_productName(catName[1])
# Out:
# ----------------------------------------------------
# TypeError          Traceback (most recent call last)
# <ipython-input-28-4b28174a5392> in <module>
# ----> 1 get_makro_productName(catName[1])
#
# TypeError: get_makro_productName() missing 1 required positional argument: 'product_type'

# %% [markdown]
# ## Print all product

# %%
pprint(product_dictionary)
# Out:
# {' HIT Expert Blooming Tea500MLx3': {'infos': {'price_kh': '28,300៛',
#                                                'price_usd': '$6.90'},
#                                      'typeOf': 'CleaningProducts'},
#  ' HIT Expert Citrus 500ML x3': {'infos': {'price_kh': '28,300៛',
#                                            'price_usd': '$6.90'},
#                                  'typeOf': 'CleaningProducts'},
#  ' HOT POT BASE-HOT 180G': {'infos': {'price_kh': '9,000៛',
#                                       'price_usd': '$2.20'},
#                             'typeOf': 'Fruits&Vegetables'},
#  ' NATURAL LOW FAT YOUHURT  500G': {'infos': {'price_kh': '11,900៛',
#                                               'price_usd': '$2.90'},
#                                     'typeOf': 'Chilled&DairyProducts'},
#  ' ONION PACK 6-7 (KG)': {'infos': {'price_kh': '7,400៛', 'price_usd': '$1.80'},
#                           'typeOf': 'Fruits&Vegetables'},
#  ' RICE CRACKER  PORK FLOSS 130G*1': {'infos': {'price_kh': '7,800៛',
#                                                 'price_usd': '$1.90'},
#                                       'typeOf': 'Fruits&Vegetables'},
#  ' Yellow corn pack': {'infos': {'price_kh': '3,300៛', 'price_usd': '$0.80'},
#                        'typeOf': 'Fruits&Vegetables'},
#  '#GRILL STOVE OTTO # GR-143': {'infos': {'price_kh': '118,500៛',
#                                           'price_usd': '$28.90'},
#                                 'typeOf': 'ElectricAppliances'},
#  '#REF 2D 8.4Q SAM#RT22FGRADST': {'infos': {'price_kh': '1,152,100៛',
#                                             'price_usd': '$281.00'},
#                                   'typeOf': 'ElectricAppliances'},
#  '#RINNAI GASS COOKER#RT-902MM(G)': {'infos': {'price_kh': '656,000៛',
#                                                'price_usd': '$160.00'},
#                                      'typeOf': 'ElectricAppliances'},
#  '#SAMSUNG65INCH#UA65AU7700KXXT SMT': {'infos': {'price_kh': '3,685,900៛',
#                                                  'price_usd': '$899.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '#SLEEPING BAG WITH HOOD': {'infos': {'price_kh': '52,900៛',
#                                        'price_usd': '$12.90'},
#                              'typeOf': 'Households'},
#  '$NIVEA MEN COOL CLICKSPRAY150MLX1': {'infos': {'price_kh': '13,100៛',
#                                                  'price_usd': '$3.20'},
#                                        'typeOf': 'PersonalCareProducts'},
#  '*AIKO KETTLE 1.7L #AK1702': {'infos': {'price_kh': '98,000៛',
#                                          'price_usd': '$23.90'},
#                                'typeOf': 'ElectricAppliances'},
#  '*BBQ Portable charcoal Grill Big': {'infos': {'price_kh': '65,200៛',
#                                                 'price_usd': '$15.90'},
#                                       'typeOf': 'Households'},
#  '*BBQ Portable charcoal GrillSmall': {'infos': {'price_kh': '43,100៛',
#                                                  'price_usd': '$10.50'},
#                                        'typeOf': 'Households'},
#  '*Bee Round vegetable TrayL#512*1p': {'infos': {'price_kh': '16,000៛',
#                                                  'price_usd': '$3.90'},
#                                        'typeOf': 'Households'},
#  '*IN HOUSE SANDWICH MAKER #SW245': {'infos': {'price_kh': '92,300៛',
#                                                'price_usd': '$22.50'},
#                                      'typeOf': 'ElectricAppliances'},
#  '*JCJ Basket#5193 *1pc': {'infos': {'price_kh': '13,500៛',
#                                      'price_usd': '$3.30'},
#                            'typeOf': 'Households'},
#  '*MYHOME HOTPOT 2.5L#JP2514/JP2515': {'infos': {'price_kh': '93,900៛',
#                                                  'price_usd': '$22.90'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*OTTO SOUP POT 3L  #SP325A': {'infos': {'price_kh': '143,500៛',
#                                           'price_usd': '$35.00'},
#                                 'typeOf': 'ElectricAppliances'},
#  '*PowerPac Electric Oven 45L#PPT45': {'infos': {'price_kh': '487,900៛',
#                                                  'price_usd': '$119.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI KR Pressure Aircon K2.420x1': {'infos': {'price_kh': '651,900៛',
#                                                  'price_usd': '$159.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI KR Pressure Washer K3 450': {'infos': {'price_kh': '938,900៛',
#                                                'price_usd': '$229.00'},
#                                      'typeOf': 'ElectricAppliances'},
#  '*SEMI_DELON. COFFEE GRINDER#KG 89': {'infos': {'price_kh': '405,900៛',
#                                                  'price_usd': '$99.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_DELON. COFFEE GRINDER#KG521': {'infos': {'price_kh': '1,184,900៛',
#                                                  'price_usd': '$289.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_DELON. COFFEE MAKER#EC785GY': {'infos': {'price_kh': '1,553,900៛',
#                                                  'price_usd': '$379.00'},
#                                        'typeOf': 'OfficeSuppliesandStationeries'},
#  '*SEMI_DELON. COFFEE MAKER#EC9335': {'infos': {'price_kh': '5,699,000៛',
#                                                 'price_usd': '$1,390.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_DELONGHI AIR FRYER#FH1163/1': {'infos': {'price_kh': '1,061,900៛',
#                                                  'price_usd': '$259.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_DLH COFFEE MAKER#ECP31.21BK': {'infos': {'price_kh': '979,900៛',
#                                                  'price_usd': '$239.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_DLH COFFEEMAKER#ECAM45.760W': {'infos': {'price_kh': '8,159,000៛',
#                                                  'price_usd': '$1,990.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER STEAM CLEAN#SC3EASY': {'infos': {'price_kh': '1,225,900៛',
#                                                  'price_usd': '$299.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER STEAM CLEAN#SE4001': {'infos': {'price_kh': '1,594,900៛',
#                                                 'price_usd': '$389.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM #T8 CLASSIC': {'infos': {'price_kh': '586,300៛',
#                                                 'price_usd': '$143.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM 14L#T14/1': {'infos': {'price_kh': '938,900៛',
#                                               'price_usd': '$229.00'},
#                                     'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM 15L#WD1 HOME': {'infos': {'price_kh': '405,900៛',
#                                                  'price_usd': '$99.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM 17L#WD3 *EU': {'infos': {'price_kh': '520,700៛',
#                                                 'price_usd': '$127.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM 2 L#VC2 *KAP': {'infos': {'price_kh': '610,900៛',
#                                                  'price_usd': '$149.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM 25L#WD5 *EU': {'infos': {'price_kh': '1,225,900៛',
#                                                 'price_usd': '$299.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM#NT30 CLASSIC': {'infos': {'price_kh': '651,900៛',
#                                                  'price_usd': '$159.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM#NT38 CLASSIC': {'infos': {'price_kh': '1,020,900៛',
#                                                  'price_usd': '$249.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KARCHER VACUUM1100W#VC3PLUS': {'infos': {'price_kh': '520,700៛',
#                                                  'price_usd': '$127.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_KUVINGS JUICER#B6000S': {'infos': {'price_kh': '2,045,900៛',
#                                            'price_usd': '$499.00'},
#                                  'typeOf': 'ElectricAppliances'},
#  '*SEMI_KUVINGS JUICER#CS600': {'infos': {'price_kh': '6,109,000៛',
#                                           'price_usd': '$1,490.00'},
#                                 'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA 1D REF. 158L#HS-229L': {'infos': {'price_kh': '951,200៛',
#                                                 'price_usd': '$232.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA 1D REF. 190L#HS-268L': {'infos': {'price_kh': '1,184,900៛',
#                                                 'price_usd': '$289.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA 4D REF 544L#HQ-627WEN': {'infos': {'price_kh': '4,751,900៛',
#                                                  'price_usd': '$1,159.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA MIC-OVEN 20L#MM720CXX': {'infos': {'price_kh': '340,300៛',
#                                                  'price_usd': '$83.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA MIC-OVEN 25L#EG925AXX': {'infos': {'price_kh': '446,900៛',
#                                                  'price_usd': '$109.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA OVEN 25L#MG25EX-B': {'infos': {'price_kh': '369,000៛',
#                                              'price_usd': '$90.00'},
#                                    'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA OVEN 35L #MC35Z1-B': {'infos': {'price_kh': '381,300៛',
#                                               'price_usd': '$93.00'},
#                                     'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA SLIDE FAN16"#FS40-10N': {'infos': {'price_kh': '186,600៛',
#                                                  'price_usd': '$45.50'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_MIDEA WATER DISPEN.#JL1643S': {'infos': {'price_kh': '1,594,900៛',
#                                                  'price_usd': '$389.00'},
#                                        'typeOf': 'OfficeSuppliesandStationeries'},
#  '*SEMI_MIDEA WM TOP12K#MAE120-504T': {'infos': {'price_kh': '1,307,900៛',
#                                                  'price_usd': '$319.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RIN. GASCOOKER2B#RTC-5912SG': {'infos': {'price_kh': '1,558,000៛',
#                                                  'price_usd': '$380.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RIN. GASCOOKER2B#RTC-6912SG': {'infos': {'price_kh': '3,075,000៛',
#                                                  'price_usd': '$750.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER #RT-702SCC': {'infos': {'price_kh': '692,900៛',
#                                                  'price_usd': '$169.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER #RT-902SC': {'infos': {'price_kh': '487,900៛',
#                                                 'price_usd': '$119.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER #RT-902SCC': {'infos': {'price_kh': '512,500៛',
#                                                  'price_usd': '$125.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER 1B#RI-511A': {'infos': {'price_kh': '172,200៛',
#                                                  'price_usd': '$42.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER 1B#RI-511M': {'infos': {'price_kh': '225,500៛',
#                                                  'price_usd': '$55.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER 2B#RI-522A': {'infos': {'price_kh': '323,900៛',
#                                                  'price_usd': '$79.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER1B#RT-901SC': {'infos': {'price_kh': '266,500៛',
#                                                  'price_usd': '$65.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER2B#RI-522MM': {'infos': {'price_kh': '405,900៛',
#                                                  'price_usd': '$99.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_RINNAI GASCOOKER2B#RI-602MM': {'infos': {'price_kh': '405,900៛',
#                                                  'price_usd': '$99.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS 2D REF. 616L#RS64T5F01B4': {'infos': {'price_kh': '11,475,900៛',
#                                                  'price_usd': '$2,799.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS 4D REF. 640L#RF65A9771B1': {'infos': {'price_kh': '17,625,900៛',
#                                                  'price_usd': '$4,299.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS MICROWAVE#MG23K3515AK/ST': {'infos': {'price_kh': '373,100៛',
#                                                  'price_usd': '$91.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS MICROWAVE#MG30T5018CK/ST': {'infos': {'price_kh': '594,500៛',
#                                                  'price_usd': '$145.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS REF.365L#RT35K50342C/ST': {'infos': {'price_kh': '2,865,900៛',
#                                                 'price_usd': '$699.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS REF.383L#RT38K50658A/ST': {'infos': {'price_kh': '2,988,900៛',
#                                                 'price_usd': '$729.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS REF.631L#RH64A53F115/ST': {'infos': {'price_kh': '7,867,900៛',
#                                                 'price_usd': '$1,919.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS REF.631L#RH64A53F12/ST': {'infos': {'price_kh': '8,400,900៛',
#                                                'price_usd': '$2,049.00'},
#                                      'typeOf': 'ElectricAppliances'},
#  '*SEMI_SS WASHER FL 9KG#WW90T504DA': {'infos': {'price_kh': '2,619,900៛',
#                                                  'price_usd': '$639.00'},
#                                        'typeOf': 'OfficeSuppliesandStationeries'},
#  '*SEMI_SS WM T 16KG#WA16R6380CV/ST': {'infos': {'price_kh': '2,209,900៛',
#                                                  'price_usd': '$539.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_SSFRIDGE382L#RT38K5981SL/ST': {'infos': {'price_kh': '2,414,900៛',
#                                                  'price_usd': '$589.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI WM F9.5K#TW-BH105M4KH': {'infos': {'price_kh': '2,189,400៛',
#                                                  'price_usd': '$534.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI WM TOP14#AW-DK1500WKH': {'infos': {'price_kh': '1,799,900៛',
#                                                  'price_usd': '$439.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI WM TOP8KG#AW-J900DKH': {'infos': {'price_kh': '1,307,900៛',
#                                                 'price_usd': '$319.00'},
#                                       'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI. SLIDE FAN16"#F-ASY10': {'infos': {'price_kh': '294,800៛',
#                                                  'price_usd': '$71.90'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI. WALL FAN 16"#F-AWY10': {'infos': {'price_kh': '225,500៛',
#                                                  'price_usd': '$55.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI.2DREF.194L#GR-A25KSUK': {'infos': {'price_kh': '1,512,900៛',
#                                                  'price_usd': '$369.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI.2DREF.233L#GR-A28KSUK': {'infos': {'price_kh': '1,471,900៛',
#                                                  'price_usd': '$359.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI.SLIDE FAN 16"#F-ALY10': {'infos': {'price_kh': '256,300៛',
#                                                  'price_usd': '$62.50'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHI.TL WM 10.5#AW-DUK1150': {'infos': {'price_kh': '1,430,900៛',
#                                                  'price_usd': '$349.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TOSHIBA RICECOOKER#RC-18VRM': {'infos': {'price_kh': '2,578,900៛',
#                                                  'price_usd': '$629.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TSB BLENDER1.5L# BL-60PHRKH': {'infos': {'price_kh': '172,200៛',
#                                                  'price_usd': '$42.00'},
#                                        'typeOf': 'OfficeSuppliesandStationeries'},
#  '*SEMI_TSB KETTLE 1.7L#KT-17SH2RKH': {'infos': {'price_kh': '143,500៛',
#                                                  'price_usd': '$35.00'},
#                                        'typeOf': 'OfficeSuppliesandStationeries'},
#  '*SEMI_TSB RICECOOKER1.8L#RC-18DH2': {'infos': {'price_kh': '307,500៛',
#                                                  'price_usd': '$75.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TSB RICECOOKER1.8L#RC-18ISP': {'infos': {'price_kh': '1,594,900៛',
#                                                  'price_usd': '$389.00'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TSB RICECOOKER1.8L#RC-T18CE': {'infos': {'price_kh': '106,200៛',
#                                                  'price_usd': '$25.90'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SEMI_TSB RICECOOKER2.8L#RC-T28CE': {'infos': {'price_kh': '139,000៛',
#                                                  'price_usd': '$33.90'},
#                                        'typeOf': 'ElectricAppliances'},
#  '*SKG HOT POT 5.8L #SK38S': {'infos': {'price_kh': '163,600៛',
#                                         'price_usd': '$39.90'},
#                               'typeOf': 'ElectricAppliances'},
#  '137 Degree Almond Milk 1L*1': {'infos': {'price_kh': '14,400៛',
#                                            'price_usd': '$3.50'},
#                                  'typeOf': 'Beverages'},
#  '888 BEEF BALL BIG (N.1) 1KG': {'infos': {'price_kh': '33,600៛',
#                                            'price_usd': '$8.20'},
#                                  'typeOf': 'Chilled&DairyProducts'},
#  '888 BEEF BALL SMALL (N.1) 500G*1': {'infos': {'price_kh': '18,500៛',
#                                                 'price_usd': '$4.50'},
#                                       'typeOf': 'Chilled&DairyProducts'},
#  '888 PORK BALL BIG (N.1) 1KG': {'infos': {'price_kh': '30,800៛',
#                                            'price_usd': '$7.50'},
#                                  'typeOf': 'Chilled&DairyProducts'},
#  '888 PORK BALL SMALL (N.1) 500GX1': {'infos': {'price_kh': '16,800៛',
#                                                 'price_usd': '$4.10'},
#                                       'typeOf': 'Chilled&DairyProducts'},
#  'A50417-SOUP BOWL': {'infos': {'price_kh': '5,700៛', 'price_usd': '$1.40'},
#                       'typeOf': 'Households'},
#  'ABC Can 330mlX24': {'infos': {'price_kh': '113,600៛', 'price_usd': '$27.70'},
#                       'typeOf': 'Beverages'},
#  'ABC Pint 330mlX24': {'infos': {'price_kh': '132,000៛', 'price_usd': '$32.20'},
#                        'typeOf': 'Beverages'},
#  'ADIDAS ADIPOWER ROLL ON 50MLX3': {'infos': {'price_kh': '28,300៛',
#                                               'price_usd': '$6.90'},
#                                     'typeOf': 'PersonalCareProducts'},
#  'ADIDAS UEFA SHOWER GEL 400MLX1': {'infos': {'price_kh': '16,400៛',
#                                               'price_usd': '$4.00'},
#                                     'typeOf': 'PersonalCareProducts'},
#  'AFC VEGETABLE CRACKERS 25Gx24': {'infos': {'price_kh': '10,700៛',
#                                              'price_usd': '$2.60'},
#                                    'typeOf': 'Snacks'},
#  'AFC WHEAT CRACKERS 25Gx24': {'infos': {'price_kh': '10,700៛',
#                                          'price_usd': '$2.60'},
#                                'typeOf': 'Snacks'},
#  'AIK CHEONG Cappuccino 12S X25G X1': {'infos': {'price_kh': '18,900៛',
#                                                  'price_usd': '$4.60'},
#                                        'typeOf': 'Beverages'},
#  'AIK CHEONG Chocolate 15S X40G X1': {'infos': {'price_kh': '18,900៛',
#                                                 'price_usd': '$4.60'},
#                                       'typeOf': 'Beverages'},
#  'AIK CHEONG Latte 12S X25G X1': {'infos': {'price_kh': '18,900៛',
#                                             'price_usd': '$4.60'},
#                                   'typeOf': 'Beverages'},
#  'AIK CHEONG-Coffee Mix 50S X20G X1': {'infos': {'price_kh': '24,200៛',
#                                                  'price_usd': '$5.90'},
#                                        'typeOf': 'Beverages'},
#  "AIKCHEONG Halia Ginger Milk 50s'x20gx1": {'infos': {'price_kh': '24,200៛',
#                                                       'price_usd': '$5.90'},
#                                             'typeOf': 'Beverages'},
#  'AIR COOLER FAN AC TURBO/AC33R1': {'infos': {'price_kh': '713,400៛',
#                                               'price_usd': '$174.00'},
#                                     'typeOf': 'ElectricAppliances'},
#  'AKM YOGHURT DURIAN 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                             'price_usd': '$1.30'},
#                                   'typeOf': 'Chilled&DairyProducts'},
#  'AKM YOGHURT MIXFRUIT 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                               'price_usd': '$1.30'},
#                                     'typeOf': 'Chilled&DairyProducts'},
#  'AKM YOGHURT PASSION 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                              'price_usd': '$1.30'},
#                                    'typeOf': 'Chilled&DairyProducts'},
#  'AKM YOGURT ALOE 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                          'price_usd': '$1.30'},
#                                'typeOf': 'Chilled&DairyProducts'},
#  'AKM YOGURT PLAIN 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                           'price_usd': '$1.30'},
#                                 'typeOf': 'Chilled&DairyProducts'},
#  'AKM YOGURT STRAWBERRY 100GX4PCS': {'infos': {'price_kh': '5,300៛',
#                                                'price_usd': '$1.30'},
#                                      'typeOf': 'Chilled&DairyProducts'},
#  'ALFREDO CRISPY CRUST255G': {'infos': {'price_kh': '10,300៛',
#                                         'price_usd': '$2.50'},
#                               'typeOf': 'Bakery'},
#  'ALMOND LAVAS 300G*1': {'infos': {'price_kh': '18,500៛', 'price_usd': '$4.50'},
#                          'typeOf': 'Bakery'},
#  'ANCHOR SALTED BUTTER 227GX1': {'infos': {'price_kh': '14,400៛',
#                                            'price_usd': '$3.50'},
#                                  'typeOf': 'Chilled&DairyProducts'},
#  'ANGKOR BEER PINT 640ml*12': {'infos': {'price_kh': '57,800៛',
#                                          'price_usd': '$14.10'},
#                                'typeOf': 'Beverages'},
#  'APPOLOspark. juice(White)750ml*1': {'infos': {'price_kh': '10,300៛',
#                                                 'price_usd': '$2.50'},
#                                       'typeOf': 'Beverages'},
#  'ARLA EMMENTAL SLICED CHEESE150GX1': {'infos': {'price_kh': '13,500៛',
#                                                  'price_usd': '$3.30'},
#                                        'typeOf': 'Chilled&DairyProducts'},
#  'ARLA FETA APETINA CUBES OIL265GX1': {'infos': {'price_kh': '18,000៛',
#                                                  'price_usd': '$4.40'},
#                                        'typeOf': 'Chilled&DairyProducts'},
#  'ARLA FETA CHEESE 200GX1': {'infos': {'price_kh': '13,500៛',
#                                        'price_usd': '$3.30'},
#                              'typeOf': 'Chilled&DairyProducts'},
#  'ARLA GOUDA SLICED CHEESE 150GX1': {'infos': {'price_kh': '13,500៛',
#                                                'price_usd': '$3.30'},
#                                      'typeOf': 'Chilled&DairyProducts'},
#  'ARM & HAMMER BACKING SODA 454gx1': {'infos': {'price_kh': '7,800៛',
#                                                 'price_usd': '$1.90'},
#                                       'typeOf': 'Bakery'},
#  'ARO ALUMINIUM  45CM  45M': {'infos': {'price_kh': '40,600៛',
#                                         'price_usd': '$9.90'},
#                               'typeOf': 'Households'},
#  'ARO BAKERY NO 40 1*100': {'infos': {'price_kh': '22,600៛',
#                                       'price_usd': '$5.50'},
#                             'typeOf': 'Households'},
#  'ARO BATHGEL LAVENDER 3500ML*1': {'infos': {'price_kh': '32,400៛',
#                                              'price_usd': '$7.90'},
#                                    'typeOf': 'PersonalCareProducts'},
#  'ARO BLANKET 6 FEET.': {'infos': {'price_kh': '151,700៛',
#                                    'price_usd': '$37.00'},
#                          'typeOf': 'Households'},
#  'ARO CHILLI SAUCE 10GX100 SACHET': {'infos': {'price_kh': '9,000៛',
#                                                'price_usd': '$2.20'},
#                                      'typeOf': 'DryGroceries'},
#  'ARO COMFORTERCASE 70"X90"': {'infos': {'price_kh': '69,700៛',
#                                          'price_usd': '$17.00'},
#                                'typeOf': 'Households'},
#  'ARO COTTON BUD 4*200': {'infos': {'price_kh': '14,400៛',
#                                     'price_usd': '$3.50'},
#                           'typeOf': 'PersonalCareProducts'},
#  'ARO COTTON BUD GOLD 4*36': {'infos': {'price_kh': '4,100៛',
#                                         'price_usd': '$1.00'},
#                               'typeOf': 'PersonalCareProducts'},
#  'ARO COTTON BUD SILVER 4X36': {'infos': {'price_kh': '4,100៛',
#                                           'price_usd': '$1.00'},
#                                 'typeOf': 'PersonalCareProducts'},
#  'ARO CREAM BATH 20ML.*100': {'infos': {'price_kh': '59,500៛',
#                                         'price_usd': '$14.50'},
#                               'typeOf': 'PersonalCareProducts'},
#  'ARO LONGAN IN SYRUP 565GX3': {'infos': {'price_kh': '22,600៛',
#                                           'price_usd': '$5.50'},
#                                 'typeOf': 'DryGroceries'},
#  'ARO LYCHEE IN SYRUP 565GX3': {'infos': {'price_kh': '22,600៛',
#                                           'price_usd': '$5.50'},
#                                 'typeOf': 'DryGroceries'},
#  'ARO MELAMINE BOWL 8" WHITE 1X6': {'infos': {'price_kh': '15,200៛',
#                                               'price_usd': '$3.70'},
#                                     'typeOf': 'Households'},
#  'ARO MELAMINE LADLE WHITE 1X6': {'infos': {'price_kh': '16,000៛',
#                                             'price_usd': '$3.90'},
#                                   'typeOf': 'Households'},
#  'ARO MINI COTTON BUD 100X6': {'infos': {'price_kh': '6,200៛',
#                                          'price_usd': '$1.50'},
#                                'typeOf': 'PersonalCareProducts'},
#  'ARO NYLON BROOM 30"': {'infos': {'price_kh': '14,400៛', 'price_usd': '$3.50'},
#                          'typeOf': 'CleaningProducts'},
#  'ARO OUDERVE 11.5" WHITE 1X2': {'infos': {'price_kh': '32,400៛',
#                                            'price_usd': '$7.90'},
#                                  'typeOf': 'Households'},
#  'ARO PASTA ELBOW 1000G.X1': {'infos': {'price_kh': '9,000៛',
#                                         'price_usd': '$2.20'},
#                               'typeOf': 'DryGroceries'},
#  'ARO PASTA SPAGHETTI 1000G.X1': {'infos': {'price_kh': '7,800៛',
#                                             'price_usd': '$1.90'},
#                                   'typeOf': 'DryGroceries'},
#  'ARO PASTA SPAGHETTI 3000G.X1': {'infos': {'price_kh': '22,600៛',
#                                             'price_usd': '$5.50'},
#                                   'typeOf': 'DryGroceries'},
#  'ARO PP CUP 22 OZ 1X50': {'infos': {'price_kh': '9,800៛',
#                                      'price_usd': '$2.40'},
#                            'typeOf': 'Households'},
#  'ARO RAMBUTAN IN SYRUP 565GX3': {'infos': {'price_kh': '22,600៛',
#                                             'price_usd': '$5.50'},
#                                   'typeOf': 'DryGroceries'},
#  'ARO SHAMPOO LAVENDER3500ML*1': {'infos': {'price_kh': '16,000៛',
#                                             'price_usd': '$3.90'},
#                                   'typeOf': 'PersonalCareProducts'},
#  'ARO SHAMPOO LEMONGRASS 3500ML*1': {'infos': {'price_kh': '32,400៛',
#                                                'price_usd': '$7.90'},
#                                      'typeOf': 'PersonalCareProducts'},
#  'ARO SHAMPOO NORMAL HAIR 3500ML.X1': {'infos': {'price_kh': '32,400៛',
#                                                  'price_usd': '$7.90'},
#                                        'typeOf': 'PersonalCareProducts'},
#  'ARO SHAMPOO YOGURT 3500ML.*1': {'infos': {'price_kh': '32,400៛',
#                                             'price_usd': '$7.90'},
#                                   'typeOf': 'PersonalCareProducts'},
#  'ARO SOAP 10G.*100': {'infos': {'price_kh': '14,400៛', 'price_usd': '$3.50'},
#                        'typeOf': 'PersonalCareProducts'},
#  'ARO SOAP GOLD 15G.*36': {'infos': {'price_kh': '14,400៛',
#                                      'price_usd': '$3.50'},
#                            'typeOf': 'PersonalCareProducts'},
#  'ARO SOAP SILVER 15G.*36': {'infos': {'price_kh': '12,300៛',
#                                        'price_usd': '$3.00'},
#                              'typeOf': 'PersonalCareProducts'},
#  'ARO SOFTENER 3800MLX1 PINK': {'infos': {'price_kh': '11,500៛',
#                                           'price_usd': '$2.80'},
#                                 'typeOf': 'CleaningProducts'},
#  'ARO SOYBEAN OIL (REFILL) 800 ML*3': {'infos': {'price_kh': '21,700៛',
#                                                  'price_usd': '$5.30'},
#                                        'typeOf': 'DryGroceries'},
#  'ARO SOYBEAN OIL 5 LITRE *1': {'infos': {'price_kh': '47,600៛',
#                                           'price_usd': '$11.60'},
#                                 'typeOf': 'DryGroceries'},
#  'ARO SPOON FORK SET PS 1X50 PAIR': {'infos': {'price_kh': '9,000៛',
#                                                'price_usd': '$2.20'},
#                                      'typeOf': 'Households'},
#  'ARO SPOON STRAW SP-824': {'infos': {'price_kh': '15,200៛',
#                                       'price_usd': '$3.70'},
#                             'typeOf': 'Households'},
#  'ARO STRAWS 100 PCS. 1X5': {'infos': {'price_kh': '11,900៛',
#                                        'price_usd': '$2.90'},
#                              'typeOf': 'Households'},
#  'ARO TOMATO SAUCE 5000G.X1': {'infos': {'price_kh': '24,200៛',
#                                          'price_usd': '$5.90'},
#                                'typeOf': 'DryGroceries'},
#  'ARO TOPPING BLUEBERRY 1.2KG.X1': {'infos': {'price_kh': '11,100៛',
#                                               'price_usd': '$2.70'},
#                                     'typeOf': 'Bakery'},
#  'ARO TOPPING STRAWBERRY 1.2KG.X1': {'infos': {'price_kh': '11,100៛',
#                                                'price_usd': '$2.70'},
#                                      'typeOf': 'Bakery'},
#  'ARO VERMICELLI 500G*1': {'infos': {'price_kh': '7,400៛',
#                                      'price_usd': '$1.80'},
#                            'typeOf': 'DryGroceries'},
#  'ARO YELLOW NOODLES 350G*3': {'infos': {'price_kh': '17,600៛',
#                                          'price_usd': '$4.30'},
#                                'typeOf': 'DryGroceries'},
#  'ARS JET GREEN LAVENDER 600ML.X3': {'infos': {'price_kh': '37,700៛',
#                                                'price_usd': '$9.20'},
#                                      'typeOf': 'CleaningProducts'},
#  'ARS JET TERMITE LAVENDER 600MLX3': {'infos': {'price_kh': '37,700៛',
#                                                 'price_usd': '$9.20'},
#                                       'typeOf': 'CleaningProducts'},
#  'ARS NOMAT CORDLESS PLUS30 X 1': {'infos': {'price_kh': '10,300៛',
#                                              'price_usd': '$2.50'},
#                                    'typeOf': 'CleaningProducts'},
#  'AU BEEF STRIPLOIN STEAK (KG)': {'infos': {'price_kh': '66,400៛',
#                                             'price_usd': '$16.20'},
#                                   'typeOf': 'Butchery'},
#  'AYAM Baked Beans Light 230G*3': {'infos': {'price_kh': '12,700៛',
#                                              'price_usd': '$3.10'},
#                                    'typeOf': 'DryGroceries'},
#  'AYAM Baked Beans Tomato 230G*3': {'infos': {'price_kh': '12,700៛',
#                                               'price_usd': '$3.10'},
#                                     'typeOf': 'DryGroceries'},
#  'AYAM Sardine Tomato Sauce 155G*10': {'infos': {'price_kh': '66,800៛',
#                                                  'price_usd': '$16.30'},
#                                        'typeOf': 'DryGroceries'},
#  'AYAM SardineOliveOil&Chilli120G*1': {'infos': {'price_kh': '11,100៛',
#                                                  'price_usd': '$2.70'},
#                                        'typeOf': 'DryGroceries'},
#  'AYAM Tuna Chilli X3 160Gx3': {'infos': {'price_kh': '23,800៛',
#                                           'price_usd': '$5.80'},
#                                 'typeOf': 'DryGroceries'},
#  'AYAM Tuna Chunks In Water 150Gx3': {'infos': {'price_kh': '23,800៛',
#                                                 'price_usd': '$5.80'},
#                                       'typeOf': 'DryGroceries'},
#  'AYAM Tuna Hot Mayonnaise 160Gx3': {'infos': {'price_kh': '23,800៛',
#                                                'price_usd': '$5.80'},
#                                      'typeOf': 'DryGroceries'},
#  'AYAM Tuna Mild Mayonnaise 160Gx3': {'infos': {'price_kh': '23,800៛',
#                                                 'price_usd': '$5.80'},
#                                       'typeOf': 'DryGroceries'},
#  'AYAM Tuna Olive Oil 100% 150Gx3': {'infos': {'price_kh': '29,500៛',
#                                                'price_usd': '$7.20'},
#                                      'typeOf': 'DryGroceries'},
#  'AYAM Tuna Tomato Chilli 160Gx3': {'infos': {'price_kh': '23,800៛',
#                                               'price_usd': '$5.80'},
#                                     'typeOf': 'DryGroceries'},
#  'AYAM Tuna in Sunflower Oil 150Gx3': {'infos': {'price_kh': '23,800៛',
#                                                  'price_usd': '$5.80'},
#                                        'typeOf': 'DryGroceries'},
#  'AYAM TunaChunks InOliveOil 150Gx3': {'infos': {'price_kh': '23,800៛',
#                                                  'price_usd': '$5.80'},
#                                        'typeOf': 'DryGroceries'},
#  'AYAM TunaLightMineralWater 150Gx3': {'infos': {'price_kh': '23,800៛',
#                                                  'price_usd': '$5.80'},
#                                        'typeOf': 'DryGroceries'},
#  'AYAM TunaSpreadInMayonnaise160Gx3': {'infos': {'price_kh': '23,800៛',
#                                                  'price_usd': '$5.80'},
#                                        'typeOf': 'DryGroceries'},
#  'Aalst Almond MilkChocolate 150gx1': {'infos': {'price_kh': '21,300៛',
#                                                  'price_usd': '$5.20'},
#                                        'typeOf': 'Snacks'},
#  'Aalst Fruit&Nuts Chocolate 150gx1': {'infos': {'price_kh': '21,300៛',
#                                                  'price_usd': '$5.20'},
#                                        'typeOf': 'Snacks'},
#  'Aalst Hazelnut Chocolate 150gx1': {'infos': {'price_kh': '21,300៛',
#                                                'price_usd': '$5.20'},
#                                      'typeOf': 'Snacks'},
#  'Africa Water melon piece': {'infos': {'price_kh': '10,700៛',
#                                         'price_usd': '$2.60'},
#                               'typeOf': 'Fruits&Vegetables'},
#  'Aluminum Paper-Short 1x1pcs': {'infos': {'price_kh': '6,200៛',
#                                            'price_usd': '$1.50'},
#                                  'typeOf': 'Households'},
#  'Anchor Pint 330mlX24': {'infos': {'price_kh': '59,500៛',
#                                     'price_usd': '$14.50'},
#                           'typeOf': 'Beverages'},
#  'Anchor white can beer 330mlx24': {'infos': {'price_kh': '38,100៛',
#                                               'price_usd': '$9.30'},
#                                     'typeOf': 'Beverages'},
#  'Angkor Beer Can 330ml X 24 Cans': {'infos': {'price_kh': '44,300៛',
#                                                'price_usd': '$10.80'},
#                                      'typeOf': 'Beverages'},
#  'Angkor Beer Pint 330ml X 24': {'infos': {'price_kh': '59,500៛',
#                                            'price_usd': '$14.50'},
#                                  'typeOf': 'Beverages'},
#  'Apollo Banana Layer Cake18g*24': {'infos': {'price_kh': '11,100៛',
#                                               'price_usd': '$2.70'},
#                                     'typeOf': 'Snacks'},
#  'Apollo Checker Choco Wafer18g*24': {'infos': {'price_kh': '10,700៛',
#                                                 'price_usd': '$2.60'},
#                                       'typeOf': 'Snacks'},
#  'Apollo Checker Straw Wafer18g*24': {'infos': {'price_kh': '10,700៛',
#                                                 'price_usd': '$2.60'},
#                                       'typeOf': 'Snacks'},
#  'Apsara Riz Jasmine Rice 5kgx1': {'infos': {'price_kh': '22,600៛',
#                                              'price_usd': '$5.50'},
#                                    'typeOf': 'DryGroceries'},
#  'Arla Mozzarella Shredded 175g*1': {'infos': {'price_kh': '16,000៛',
#                                                'price_usd': '$3.90'},
#                                      'typeOf': 'Chilled&DairyProducts'},
#  'Arla Mozzarella Shredded 175g*12': {'infos': {'price_kh': '162,400៛',
#                                                 'price_usd': '$39.60'},
#                                       'typeOf': 'Chilled&DairyProducts'},
#  'ArlaMilk FullCream 3.5% 1000ml*1': {'infos': {'price_kh': '6,600៛',
#                                                 'price_usd': '$1.60'},
#                                       'typeOf': 'Beverages'},
#  'ArlaMilk FullCream 3.5% 1000ml*12': {'infos': {'price_kh': '76,700៛',
#                                                  'price_usd': '$18.70'},
#                                        'typeOf': 'Beverages'},
#  'Aro Fragrand Rice 5kgx1': {'infos': {'price_kh': '17,200៛',
#                                        'price_usd': '$4.20'},
#                              'typeOf': 'DryGroceries'},
#  'Aro Jasmine Rice 5kgx1': {'infos': {'price_kh': '23,800៛',
#                                       'price_usd': '$5.80'},
#                             'typeOf': 'DryGroceries'},
#  'Ashtray #TA5802 1x1pcs': {'infos': {'price_kh': '9,400៛',
#                                       'price_usd': '$2.30'},
#                             'typeOf': 'Households'},
#  'BABIMILD BOTTLE&NIPPLE CLEAN650ML': {'infos': {'price_kh': '10,300៛',
#                                                  'price_usd': '$2.50'},
#                                        'typeOf': 'CleaningProducts'},
#  'BABY CHINESE CABBAGE 250g*1': {'infos': {'price_kh': '4,900៛',
#                                            'price_usd': '$1.20'},
#                                  'typeOf': 'Fruits&Vegetables'},
#  "BABY LOVE EASY TAPE MEGA-M 84'SX1": {'infos': {'price_kh': '51,300៛',
#                                                  'price_usd': '$12.50'},
#                                        'typeOf': 'PersonalCareProducts'},
#  'BABY LOVE PLAYPANT ULTRADRY-L54X1': {'infos': {'price_kh': '55,400៛',
#                                                  'price_usd': '$13.50'},
#                                        'typeOf': 'PersonalCareProducts'},
#  'BABY LOVE PLAYPANT ULTRDRY-XL48X1': {'infos': {'price_kh': '59,500៛',
#                                                  'price_usd': '$14.50'},
#                                        'typeOf': 'PersonalCareProducts'},
#  'BABYLOVE DAY NIGHT PANTS JP L44X1': {'infos': {'price_kh': '34,400៛',
#                                                  'price_usd': '$8.40'},
#                                        'typeOf': 'PersonalCareProducts'},
#  'BAMBOO SHOOTSTRIP IN BRINE': {'infos': {'price_kh': '12,300៛',
#                                           'price_usd': '$3.00'},
#                                 'typeOf': 'Fruits&Vegetables'},
#  'BAN PAI FERMENTED PORK 160 GX1': {'infos': {'price_kh': '18,500៛',
#                                               'price_usd': '$4.50'},
#                                     'typeOf': 'Chilled&DairyProducts'},
#  'BANANA CUP CAKE55G.*8': {'infos': {'price_kh': '9,800៛',
#                                      'price_usd': '$2.40'},
#                            'typeOf': 'Bakery'},
#  'BARLEY 500 G': {'infos': {'price_kh': '6,600៛', 'price_usd': '$1.60'},
#                   'typeOf': 'Fruits&Vegetables'},
#  'BBQ Gun lighter S-HB-088 1*2pcs': {'infos': {'price_kh': '11,500៛',
#                                                'price_usd': '$2.80'},
#                                      'typeOf': 'Households'},
#  'BBQ Spark Gun lighter L 1*1pcs': {'infos': {'price_kh': '16,000៛',
#                                               'price_usd': '$3.90'},
#                                     'typeOf': 'Households'},
#  'BEEF CHUCK ROLL CUT/SLICE  KG.': {'infos': {'price_kh': '40,600៛',
#                                               'price_usd': '$9.90'},
#                                     'typeOf': 'Butchery'},
#  'BEEF CHUCK ROLL MINCE (KG)': {'infos': {'price_kh': '43,100៛',
#                                           'price_usd': '$10.50'},
#                                 'typeOf': 'Butchery'},
#  'BEEF ROUND MINCE (KG)': {'infos': {'price_kh': '43,100៛',
#                                      'price_usd': '$10.50'},
#                            'typeOf': 'Butchery'},
#  'BEEF ROUND SLICE (KG)': {'infos': {'price_kh': '41,800៛',
#                                      'price_usd': '$10.20'},
#                            'typeOf': 'Butchery'},
#  'BENTO CUTT FISH PRUNGROS 5G.X12': {'infos': {'price_kh': '9,400៛',
#                                                'price_usd': '$2.30'},
#                                      'typeOf': 'Snacks'},
#  'BENTO CUTTLE FISH5G.X12': {'infos': {'price_kh': '9,400៛',
#                                        'price_usd': '$2.30'},
#                              'typeOf': 'Snacks'},
#  'BEST FOOD MAGARINE 150GX3': {'infos': {'price_kh': '16,400៛',
#                                          'price_usd': '$4.00'},
#                                'typeOf': 'OfficeSuppliesandStationeries'},
#  'BETAGEN DKY ORANGE 140MLX4PCS': {'infos': {'price_kh': '10,700៛',
#                                              'price_usd': '$2.60'},
#                                    'typeOf': 'Chilled&DairyProducts'},
#  'BETAGEN DKY ORANGE 300ML.': {'infos': {'price_kh': '6,200៛',
#                                          'price_usd': '$1.50'},
#                                'typeOf': 'Chilled&DairyProducts'},
#  'BETAGEN DKY ORANGE 700MLX1': {'infos': {'price_kh': '9,800៛',
#                                           'price_usd': '$2.40'},
#                                 'typeOf': 'Chilled&DairyProducts'},
#  'BETAGEN DKY ORANGE 85MLX6PCS': {'infos': {'price_kh': '9,000៛',
#                                             'price_usd': '$2.20'},
#                                   'typeOf': 'Chilled&DairyProducts'},
#  'BIO-OIL SKIN CARE OIL 25MLX2': {'infos': {'price_kh': '30,800៛',
#                                             'price_usd': '$7.50'},
#                                   'typeOf': 'PersonalCareProducts'},
#  'BISCUIT TOPPO COCOA 11G.X12': {'infos': {'price_kh': '11,100៛',
#                                            'price_usd': '$2.70'},
#                                  'typeOf': 'Snacks'},
#  'BLACK BEAN 1Kg': {'infos': {'price_kh': '15,600៛', 'price_usd': '$3.80'},
#                     'typeOf': 'Fruits&Vegetables'},
#  'BLACK BEAN 500 G': {'infos': {'price_kh': '7,800៛', 'price_usd': '$1.90'},
#                       'typeOf': 'Fruits&Vegetables'},
#  'BLACK PEPPER CORN 1KG': {'infos': {'price_kh': '36,500៛',
#                                      'price_usd': '$8.90'},
#                            'typeOf': 'DryGroceries'},
#  'BLACK PEPPER CORN 200G': {'infos': {'price_kh': '9,000៛',
#                                       'price_usd': '$2.20'},
#                             'typeOf': 'DryGroceries'},
#  'BLACK PEPPER CORN 500G': {'infos': {'price_kh': '19,700៛',
#                                       'price_usd': '$4.80'},
#                             'typeOf': 'DryGroceries'},
#  'BLACK PEPPER CORN GRINDER 180G': {'infos': {'price_kh': '24,200៛',
#                                               'price_usd': '$5.90'},
#                                     'typeOf': 'DryGroceries'},
#  'BLACK SESAME 1Kg': {'infos': {'price_kh': '39,000៛', 'price_usd': '$9.50'},
#                       'typeOf': 'Fruits&Vegetables'},
#  'BLACKBERRY 1*170G. - PACK': {'infos': {'price_kh': '29,500៛',
#                                          'price_usd': '$7.20'},
#                                'typeOf': 'Fruits&Vegetables'},
#  'BLENDER OTTO #BE-120  1L': {'infos': {'price_kh': '96,400៛',
#                                         'price_usd': '$23.50'},
#                               'typeOf': 'ElectricAppliances'},
# ...
#                                       'typeOf': 'DryGroceries'},
#  'TUMTIM SIAM POMELO': {'infos': {'price_kh': '24,200៛', 'price_usd': '$5.90'},
#                         'typeOf': 'Fruits&Vegetables'},
#  'Tapioca pearl ball pack 500g': {'infos': {'price_kh': '4,500៛',
#                                             'price_usd': '$1.10'},
#                                   'typeOf': 'Fruits&Vegetables'},
#  'Teisseire syrup caramel 1L*1': {'infos': {'price_kh': '36,500៛',
#                                             'price_usd': '$8.90'},
#                                   'typeOf': 'Beverages'},
#  'Three lady Mackerel In Tomato Sauce 155gx10': {'infos': {'price_kh': '26,700៛',
#                                                            'price_usd': '$6.50'},
#                                                  'typeOf': 'OfficeSuppliesandStationeries'},
#  'Tiger Can 330mlX24': {'infos': {'price_kh': '53,700៛', 'price_usd': '$13.10'},
#                         'typeOf': 'Beverages'},
#  'Tiger Crystal 330mlX24': {'infos': {'price_kh': '75,000៛',
#                                       'price_usd': '$18.30'},
#                             'typeOf': 'Beverages'},
#  'Tiger Crystal Can 330mlX24': {'infos': {'price_kh': '57,800៛',
#                                           'price_usd': '$14.10'},
#                                 'typeOf': 'Beverages'},
#  'Tiger Pint 330mlX24': {'infos': {'price_kh': '68,500៛',
#                                    'price_usd': '$16.70'},
#                          'typeOf': 'Beverages'},
#  'Triton Car shampoo Berry 1L x1pcs': {'infos': {'price_kh': '15,600៛',
#                                                  'price_usd': '$3.80'},
#                                        'typeOf': 'CleaningProducts'},
#  'Triton Car shampoo Ozone 1L x1pcs': {'infos': {'price_kh': '15,600៛',
#                                                  'price_usd': '$3.80'},
#                                        'typeOf': 'CleaningProducts'},
#  'UFC Ice Coffee 180ml*6': {'infos': {'price_kh': '10,300៛',
#                                       'price_usd': '$2.50'},
#                             'typeOf': 'Beverages'},
#  'UFM WHEAT FLOUR RED LOTUS 1KG*1': {'infos': {'price_kh': '10,300៛',
#                                                'price_usd': '$2.50'},
#                                      'typeOf': 'Bakery'},
#  'UFM WHEAT FLOUR TRA FAN 1KG*1': {'infos': {'price_kh': '8,600៛',
#                                              'price_usd': '$2.10'},
#                                    'typeOf': 'Bakery'},
#  'UFM WHEAT FLOUR WHITE SWAN1KG*1': {'infos': {'price_kh': '8,200៛',
#                                                'price_usd': '$2.00'},
#                                      'typeOf': 'Bakery'},
#  "UNIDRY EXTRA SOFT PADS L 20'SX1": {'infos': {'price_kh': '16,000៛',
#                                                'price_usd': '$3.90'},
#                                      'typeOf': 'PersonalCareProducts'},
#  "UNIDRY EXTRA SOFT PADS L 54'SX1": {'infos': {'price_kh': '40,600៛',
#                                                'price_usd': '$9.90'},
#                                      'typeOf': 'PersonalCareProducts'},
#  "UNIDRY EXTRA SOFT PADS M 60'SX1": {'infos': {'price_kh': '39,000៛',
#                                                'price_usd': '$9.50'},
#                                      'typeOf': 'PersonalCareProducts'},
#  "UNIDRY EXTRA SOFT PADS XL 48'SX1": {'infos': {'price_kh': '39,000៛',
#                                                 'price_usd': '$9.50'},
#                                       'typeOf': 'PersonalCareProducts'},
#  "UNIDRY EXTRA SOFT PADS XXL 42'SX1": {'infos': {'price_kh': '36,900៛',
#                                                  'price_usd': '$9.00'},
#                                        'typeOf': 'PersonalCareProducts'},
#  "UNIDRY NEW BORN 36'SX1": {'infos': {'price_kh': '16,800៛',
#                                       'price_usd': '$4.10'},
#                             'typeOf': 'PersonalCareProducts'},
#  'US F AN CHUCK EYE ROLL SLICE 250': {'infos': {'price_kh': '22,600៛',
#                                                 'price_usd': '$5.50'},
#                                       'typeOf': 'OfficeSuppliesandStationeries'},
#  'VASELINE INSTANT SERUM320ML*1': {'infos': {'price_kh': '21,300៛',
#                                              'price_usd': '$5.20'},
#                                    'typeOf': 'PersonalCareProducts'},
#  'VASELINE LOTION PINK 400ML*1': {'infos': {'price_kh': '22,100៛',
#                                             'price_usd': '$5.40'},
#                                   'typeOf': 'PersonalCareProducts'},
#  'VASELINE LOTION SPF24 350ML*1': {'infos': {'price_kh': '24,200៛',
#                                              'price_usd': '$5.90'},
#                                    'typeOf': 'PersonalCareProducts'},
#  'VASELINE SPF30 SERUM 320ML*1': {'infos': {'price_kh': '21,300៛',
#                                             'price_usd': '$5.20'},
#                                   'typeOf': 'PersonalCareProducts'},
#  'VERMICELLI SOUP MIXTURE SET100GX1': {'infos': {'price_kh': '8,200៛',
#                                                  'price_usd': '$2.00'},
#                                        'typeOf': 'Fruits&Vegetables'},
#  'VICTORY Manual Juice Press(L)1pcs': {'infos': {'price_kh': '81,600៛',
#                                                  'price_usd': '$19.90'},
#                                        'typeOf': 'Households'},
#  'VIET HUNG Mixed Fruit Chips250g*1': {'infos': {'price_kh': '7,800៛',
#                                                  'price_usd': '$1.90'},
#                                        'typeOf': 'Snacks'},
#  'VISO PISES ANTIBAC 3.7KGX1': {'infos': {'price_kh': '24,200៛',
#                                           'price_usd': '$5.90'},
#                                 'typeOf': 'CleaningProducts'},
#  'VISO PISES LQ MOR-BLOOM 3300MLX1': {'infos': {'price_kh': '32,400៛',
#                                                 'price_usd': '$7.90'},
#                                       'typeOf': 'CleaningProducts'},
#  'VISO PISES LQ PERFUME 3300MLX1': {'infos': {'price_kh': '32,400៛',
#                                               'price_usd': '$7.90'},
#                                     'typeOf': 'CleaningProducts'},
#  'VISO PISES Paris Perfume 3700Gx1': {'infos': {'price_kh': '22,600៛',
#                                                 'price_usd': '$5.50'},
#                                       'typeOf': 'CleaningProducts'},
#  'VISO PISES REFRESH SCARLET 400GX1': {'infos': {'price_kh': '2,900៛',
#                                                  'price_usd': '$0.70'},
#                                        'typeOf': 'CleaningProducts'},
#  'VISO PISES REFRSH(KH) 4000Gx1': {'infos': {'price_kh': '24,200៛',
#                                              'price_usd': '$5.90'},
#                                    'typeOf': 'CleaningProducts'},
#  'VITAL DRINKING WATER 1500ML 1X 12': {'infos': {'price_kh': '18,900៛',
#                                                  'price_usd': '$4.60'},
#                                        'typeOf': 'Beverages'},
#  'VITAL DRINKING WATER 500ML 1X24': {'infos': {'price_kh': '13,900៛',
#                                                'price_usd': '$3.40'},
#                                      'typeOf': 'Beverages'},
#  'VITALIA Merlot Sangiovese 3Lx1': {'infos': {'price_kh': '91,000៛',
#                                               'price_usd': '$22.20'},
#                                     'typeOf': 'Beverages'},
#  'WAI WAI INSTANT DUCK FLAVOR60G*30': {'infos': {'price_kh': '25,400៛',
#                                                  'price_usd': '$6.20'},
#                                        'typeOf': 'DryGroceries'},
#  'WAI WAI MINCED PORK 60G.X30': {'infos': {'price_kh': '25,400៛',
#                                            'price_usd': '$6.20'},
#                                  'typeOf': 'DryGroceries'},
#  'WD Seaweed Laver Less Salted 5GX9': {'infos': {'price_kh': '16,000៛',
#                                                  'price_usd': '$3.90'},
#                                        'typeOf': 'Snacks'},
#  'WD Seaweed Laver Original 5GX9': {'infos': {'price_kh': '16,000៛',
#                                               'price_usd': '$3.90'},
#                                     'typeOf': 'Snacks'},
#  'WHEAT FLOUR FOR BREAD 5KG*1': {'infos': {'price_kh': '29,500៛',
#                                            'price_usd': '$7.20'},
#                                  'typeOf': 'Bakery'},
#  'WHITE SESAME 1Kg': {'infos': {'price_kh': '27,500៛', 'price_usd': '$6.70'},
#                       'typeOf': 'Fruits&Vegetables'},
#  'WHITE SESAME 500 G': {'infos': {'price_kh': '14,400៛', 'price_usd': '$3.50'},
#                         'typeOf': 'Fruits&Vegetables'},
#  'WHITE SHIMEJI MUSHROOM 125g': {'infos': {'price_kh': '3,700៛',
#                                            'price_usd': '$0.90'},
#                                  'typeOf': 'Fruits&Vegetables'},
#  'WHOLE WHEAT BREAD 650G.': {'infos': {'price_kh': '8,200៛',
#                                        'price_usd': '$2.00'},
#                              'typeOf': 'Bakery'},
#  'WINE OPENER ARO': {'infos': {'price_kh': '22,600៛', 'price_usd': '$5.50'},
#                      'typeOf': 'Households'},
#  'WINNER Manual Juice Press(L) 1pcs': {'infos': {'price_kh': '52,900៛',
#                                                  'price_usd': '$12.90'},
#                                        'typeOf': 'Households'},
#  'WOLF BLASS SHIRAZCABERNET 750ML*1': {'infos': {'price_kh': '68,100៛',
#                                                  'price_usd': '$16.60'},
#                                        'typeOf': 'Beverages'},
#  'WURKZ ENERGY DRINK 250ML 1X24C': {'infos': {'price_kh': '51,300៛',
#                                               'price_usd': '$12.50'},
#                                     'typeOf': 'Beverages'},
#  'Water bottle#5210 2.1L 181': {'infos': {'price_kh': '18,500៛',
#                                           'price_usd': '$4.50'},
#                                 'typeOf': 'Households'},
#  'White Castle Butter Cookies 681gx1': {'infos': {'price_kh': '29,900៛',
#                                                   'price_usd': '$7.30'},
#                                         'typeOf': 'Snacks'},
#  'White Castle Butter Cookies 908gx1': {'infos': {'price_kh': '40,600៛',
#                                                   'price_usd': '$9.90'},
#                                         'typeOf': 'Snacks'},
#  'White Castle ButterCookies 400gx1': {'infos': {'price_kh': '18,500៛',
#                                                  'price_usd': '$4.50'},
#                                        'typeOf': 'Snacks'},
#  'White Pepper Ground-pack100g*2': {'infos': {'price_kh': '26,700៛',
#                                               'price_usd': '$6.50'},
#                                     'typeOf': 'DryGroceries'},
#  'Wine B&G   Beaujolais 75clx1': {'infos': {'price_kh': '54,500៛',
#                                             'price_usd': '$13.30'},
#                                   'typeOf': 'Beverages'},
#  'Wine B&G  Bordeaux 75clx1': {'infos': {'price_kh': '54,500៛',
#                                          'price_usd': '$13.30'},
#                                'typeOf': 'Beverages'},
#  'YELLOW DRAGON FRUIT CAT 10 KG': {'infos': {'price_kh': '14,800៛',
#                                              'price_usd': '$3.60'},
#                                    'typeOf': 'Fruits&Vegetables'},
#  'YELLOW PLUM TOMATO 500 G': {'infos': {'price_kh': '7,400៛',
#                                         'price_usd': '$1.80'},
#                               'typeOf': 'Fruits&Vegetables'},
#  'YLY BEAN CURD 125G X 4PCS': {'infos': {'price_kh': '3,700៛',
#                                          'price_usd': '$0.90'},
#                                'typeOf': 'Chilled&DairyProducts'},
#  'YLY EGG TOFU 120 X 5PCS': {'infos': {'price_kh': '11,500៛',
#                                        'price_usd': '$2.80'},
#                              'typeOf': 'Chilled&DairyProducts'},
#  'YLY FRIED TOFU 500GX1': {'infos': {'price_kh': '9,000៛',
#                                      'price_usd': '$2.20'},
#                            'typeOf': 'Chilled&DairyProducts'},
#  'YLY SLIP FUZU 500GX1': {'infos': {'price_kh': '23,400៛',
#                                     'price_usd': '$5.70'},
#                           'typeOf': 'Chilled&DairyProducts'},
#  'YLY SOFT TOFU 250G X 2PCS': {'infos': {'price_kh': '2,900៛',
#                                          'price_usd': '$0.70'},
#                                'typeOf': 'Chilled&DairyProducts'},
#  'YLY TOFU 400G X1': {'infos': {'price_kh': '6,200៛', 'price_usd': '$1.50'},
#                       'typeOf': 'Chilled&DairyProducts'},
#  'YLY TOFU BOX 440G X1': {'infos': {'price_kh': '2,500៛', 'price_usd': '$0.60'},
#                           'typeOf': 'Chilled&DairyProducts'},
#  'YLY TOFU PACK 220G X 5PCS': {'infos': {'price_kh': '9,800៛',
#                                          'price_usd': '$2.40'},
#                                'typeOf': 'Chilled&DairyProducts'},
#  'YLY WET FUZU 250G X1': {'infos': {'price_kh': '10,300៛',
#                                     'price_usd': '$2.50'},
#                           'typeOf': 'Chilled&DairyProducts'},
#  'Yanyan Chocolate Hazelnut 44g*10': {'infos': {'price_kh': '29,900៛',
#                                                 'price_usd': '$7.30'},
#                                       'typeOf': 'Snacks'},
#  'Yanyan Strawberry  50g*10': {'infos': {'price_kh': '29,900៛',
#                                          'price_usd': '$7.30'},
#                                'typeOf': 'Snacks'},
#  'Yanyan Vanilla 50g*10': {'infos': {'price_kh': '29,900៛',
#                                      'price_usd': '$7.30'},
#                            'typeOf': 'Snacks'},
#  'Yanyan chocolate  50g*10': {'infos': {'price_kh': '29,900៛',
#                                         'price_usd': '$7.30'},
#                               'typeOf': 'Snacks'},
#  'Yellow Water Melon KH piece': {'infos': {'price_kh': '10,300៛',
#                                            'price_usd': '$2.50'},
#                                  'typeOf': 'Fruits&Vegetables'},
#  'Yogo Ice 45mlx4': {'infos': {'price_kh': '23,000៛', 'price_usd': '$5.60'},
#                      'typeOf': 'Snacks'},
#  'Young Radish Kimchi 380g*1': {'infos': {'price_kh': '12,700៛',
#                                           'price_usd': '$3.10'},
#                                 'typeOf': 'Chilled&DairyProducts'},
#  'ZEBRA FOOD PAN 40CM 1x1': {'infos': {'price_kh': '134,900៛',
#                                        'price_usd': '$32.90'},
#                              'typeOf': 'Households'},
#  'ZESPRI GOLD KIWI #44 - P.4': {'infos': {'price_kh': '27,100៛',
#                                           'price_usd': '$6.60'},
#                                 'typeOf': 'Fruits&Vegetables'},
#  'ZESPRI GREEN KIWI #78 - P.4': {'infos': {'price_kh': '17,600៛',
#                                            'price_usd': '$4.30'},
#                                  'typeOf': 'Fruits&Vegetables'},
#  'ZESPRI GREEN KIWI #78-P.6': {'infos': {'price_kh': '25,400៛',
#                                          'price_usd': '$6.20'},
#                                'typeOf': 'Fruits&Vegetables'},
#  'ZUMMER Aloe Vera Juice 350ml*6': {'infos': {'price_kh': '11,500៛',
#                                               'price_usd': '$2.80'},
#                                     'typeOf': 'Beverages'},
#  'cracker with sea crab100g*1': {'infos': {'price_kh': '9,800៛',
#                                            'price_usd': '$2.40'},
#                                  'typeOf': 'Bakery'},
#  'cracker&Fish Floss 100g*1': {'infos': {'price_kh': '9,800៛',
#                                          'price_usd': '$2.40'},
#                                'typeOf': 'Bakery'},
#  'cracker&spicy chicken100g*1': {'infos': {'price_kh': '9,800៛',
#                                            'price_usd': '$2.40'},
#                                  'typeOf': 'Bakery'}}

# %% [markdown]
# # Converting dict to JSON file.

# %%
def save_data(title,data):
    with open(title, "w",encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=3)

# %%
def load_data(title):
    with open(title,encoding='utf-8') as f:
        return json.load(f)

# %%
macro_store_pirce = "./data/macro_store_pirce.json"
save_data(macro_store_pirce,product_dictionary)
macro_store_pirce_list = load_data(macro_store_pirce)

# %%
macro_store_pirce_list
# Out:
# {'PANDAN COOKIES 1 KG.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'COFFEE COOKIES 1KG': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'PINEAPPLE BISCUIT': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'STRAWBERRY MINI CRACKER 580G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.70', 'price_kh': '19,300៛'}},
#  'PINEAPPLE MINI CRACKER 580 G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.70', 'price_kh': '19,300៛'}},
#  'HAM+PORK SAUSAGE PIZZA 300 G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'ARM & HAMMER BACKING SODA 454gx1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'MILK BREAD 300G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'DR.OETKER NONA PANCAKE ORIG.1KG': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'DR.OETKER NONA CORN STARCH400G': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'FOY THONG CAKE 20G.X6': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'ARO TOPPING BLUEBERRY 1.2KG.X1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'RAISIN COOKIE 300G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'ALMOND LAVAS 300G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'GARLIC BREAD (PORKFLOSS)300G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'ARO TOPPING STRAWBERRY 1.2KG.X1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'cracker&spicy chicken100g*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'cracker&Fish Floss 100g*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'SPICY PORK FLOSS 300G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'PORK FLOSS LAVAS 300G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'LITTLE FARM PIZZA BREAD58G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.20', 'price_kh': '4,900៛'}},
#  'LITTLE FARM GARLIC BREAD76G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.40', 'price_kh': '5,700៛'}},
#  'Prima Plain Flour 1kg*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'Prima Bread Flour 1kg*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.10', 'price_kh': '12,700៛'}},
#  'BRUGGEMAN YeastInstant500g*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'FZ HAWAII PIZZA PAN220G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'FZ MEXICAN PIZZA PAN 220G*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'MOCHI BUN 25 G.X 6 PCS': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'SHREDDED PORK40G.*6PCS.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.30', 'price_kh': '9,400៛'}},
#  'FANCY DONUT35G* 5PCS.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'WHOLE WHEAT BREAD 650G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'cracker with sea crab100g*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'HOT DOG BUN60G.X6': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'WHEAT FLOUR FOR BREAD 5KG*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$7.20', 'price_kh': '29,500៛'}},
#  'ALFREDO CRISPY CRUST255G': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'JELLY MASHMELO 500G X1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'UFM WHEAT FLOUR RED LOTUS 1KG*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'UFM WHEAT FLOUR TRA FAN 1KG*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'MAGARATE SODA 300G.*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'STICK CHEESE BREAD 55 G.X2 PCS.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.20', 'price_kh': '4,900៛'}},
#  'BUTTER CROISSANT 43G*4': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$3.20', 'price_kh': '13,100៛'}},
#  'EGG TART 60GX4': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'SOFT ROLL 30G.X12': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'RED BEAN BUN 50G.X6': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'RAISIN BREAD 300G.': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'BURGER BUN 60GX6': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'UFM WHEAT FLOUR WHITE SWAN1KG*1': {'typeOf': 'Bakery',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'PORK SPARE RIBS TRIMMED KG': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$6.70', 'price_kh': '27,500៛'}},
#  'PORK FORE FEET(ST) KG': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'PORK BELLY MINCE KG': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$5.80', 'price_kh': '23,800៛'}},
#  'CHICKEN BLOOD': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$0.30', 'price_kh': '1,200៛'}},
#  'BEEF CHUCK ROLL CUT/SLICE  KG.': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$9.90', 'price_kh': '40,600៛'}},
#  'BEEF ROUND SLICE (KG)': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$10.20', 'price_kh': '41,800៛'}},
#  'BEEF CHUCK ROLL MINCE (KG)': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$10.50', 'price_kh': '43,100៛'}},
#  'AU BEEF STRIPLOIN STEAK (KG)': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$16.20', 'price_kh': '66,400៛'}},
#  'BEEF ROUND MINCE (KG)': {'typeOf': 'Butchery',
#   'infos': {'price_usd': '$10.50', 'price_kh': '43,100៛'}},
#  'EMBORG YOGURT 1Lx1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'BTG DR.YOGUT STRAWBERRY 300ML*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.40', 'price_kh': '5,700៛'}},
#  'BETAGEN DKY ORANGE 300ML.': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.50', 'price_kh': '6,200៛'}},
#  'BETAGEN DKY ORANGE 140MLX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'DM DKY MIXED FRUIT 160ML*4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'F&N FRUIT TREE APPLE & ALOE VERA JUICE, 1L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'SUNKIST APPLE JUICE 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'F&N FRUIT TREE FRUIT&VEG-JUICE 1L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'F&N FRUIT TREE GUAVA JUICE 1L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'F&N FRUIT TREE APPLE JUICE 1ltrx1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'BETAGEN DKY ORANGE 700MLX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'C.P P.VIENNA SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'BETAGEN DKY ORANGE 85MLX6PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'F&N FRUIT TREE APPLE&ALO-JUICE 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'EB SPRAY CREAM 1X250ML': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.70', 'price_kh': '19,300៛'}},
#  'Emborge COOK AND BAKE Butter 250GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'E&V EXCELLENCE WHIPPING CREAM1LX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.80', 'price_kh': '27,900៛'}},
#  'JinAn Kimbab Turnip Pickle 350g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.30', 'price_kh': '9,400៛'}},
#  'JinAn turnip&Bamb.Sh.Pickle300G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'Dried Squid Stirfry 300g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.20', 'price_kh': '25,400៛'}},
#  'BTG PROK PATE 500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'KC ANGKOR PORK SAUSAGE 250G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'TGM Smoked ham (CH) 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$14.30', 'price_kh': '58,600៛'}},
#  'TGM COOKED HAM SLICED(CH) 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$11.60', 'price_kh': '47,600៛'}},
#  'Green Pepper Moo Yor Pate (500g)': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.70', 'price_kh': '27,500៛'}},
#  'Chinese Cabbage Kimchi 800g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.80', 'price_kh': '15,600៛'}},
#  'Young Radish Kimchi 380g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.10', 'price_kh': '12,700៛'}},
#  'LIM SOKHOUNG KIMCHI PLASTIC500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'LIM SOKHOUNG KIMCHI BOX 400GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'MADAM CHONGS KIMCHI 320G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'SM SWEET SOYBEAN PASTE 500G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  "MADAM CHONG'S KIMCHI  2.1KG*1": {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.90', 'price_kh': '36,500៛'}},
#  "MADAM CHONG'S KIMCHI 1.4KG*1": {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.10', 'price_kh': '29,100៛'}},
#  'MEIJI STRAWBERRY MILK 830ML*12': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$26.90', 'price_kh': '110,300៛'}},
#  'MEIJI CHOCOLATE MILK 830ML*12': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$27.60', 'price_kh': '113,200៛'}},
#  'MEIJI LOW FAT MILK 830ML*12': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$27.60', 'price_kh': '113,200៛'}},
#  'ANCHOR SALTED BUTTER 227GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'MADAM CHONGS KIMCHI 700G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.80', 'price_kh': '15,600៛'}},
#  'MEIJI STRAWBERRY MILK 830ML*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'YLY EGG TOFU 120 X 5PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'MEIJI FRESH MILK 830ML*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'MEIJI LOW FAT MILK 830ML': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'YLY BEAN CURD 125G X 4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$0.90', 'price_kh': '3,700៛'}},
#  'YLY TOFU 400G X1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.50', 'price_kh': '6,200៛'}},
#  'MEIJI PLAIN MILK 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'MEIJI CHOCOLATE MILK 830MLX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'YLY TOFU BOX 440G X1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$0.60', 'price_kh': '2,500៛'}},
#  'YLY FRIED TOFU 500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'YLY TOFU PACK 220G X 5PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'YLY SOFT TOFU 250G X 2PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$0.70', 'price_kh': '2,900៛'}},
#  'ARLA GOUDA SLICED CHEESE 150GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'EB EMMENTAL PORTION CHEESE 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.10', 'price_kh': '16,800៛'}},
#  'PSD CAMMEBERT IN METAL TIN 1X125G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'PSD BRIE IN METAL TIN 1X125G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.40', 'price_kh': '13,900៛'}},
#  'EB CREAM CHEESE 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.10', 'price_kh': '12,700៛'}},
#  'ARLA EMMENTAL SLICED CHEESE150GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'EB CHEDDAR CHEESE COLOURED 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.80', 'price_kh': '15,600៛'}},
#  'EUROLA SANDWICH HAM 500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.70', 'price_kh': '23,400៛'}},
#  'EUROLA SMOKED BACON 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$15.20', 'price_kh': '62,300៛'}},
#  'EB MATURE CHEDDAR CHEESE 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.80', 'price_kh': '15,600៛'}},
#  'EB PIZZA TOPPING 22% 1*2.3KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$22.20', 'price_kh': '91,000៛'}},
#  'Arla Mozzarella Shredded 175g*12': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$39.60', 'price_kh': '162,400៛'}},
#  'EB AMERICAN CHEDDAR SLICES 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'EB CHEDDAR SLICED PROCESSED1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.90', 'price_kh': '11,900៛'}},
#  'Arla Mozzarella Shredded 175g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.90', 'price_kh': '16,000៛'}},
#  'SERIOUSLY STRONG EXTRA MATUR 200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'EMBORG CHEDDAR  SLICED 1.033KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$11.90', 'price_kh': '48,800៛'}},
#  '888 BEEF BALL BIG (N.1) 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.20', 'price_kh': '33,600៛'}},
#  '888 PORK BALL BIG (N.1) 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.50', 'price_kh': '30,800៛'}},
#  'F&N FRUIT TREE ORANGE JUICE 1ltrx1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'CHICKEN EGG #2 COVER 30 PC*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'C.P PA-TE #1 (CIRCLE) 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  "EB PERFECT SLICE 1*2'S*200G": {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'SUNKIST ORANGE JUICE 2LX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'C.P PA-TE PREMIUM 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.70', 'price_kh': '19,300៛'}},
#  'GSB MINI SMOKY 3000 G.': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$14.90', 'price_kh': '61,100៛'}},
#  'GSB HOT DOG C GRADE 3000 G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$9.30', 'price_kh': '38,100៛'}},
#  'GSB COCKTAIL C GRADE 3000 G.*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$9.30', 'price_kh': '38,100៛'}},
#  'BAN PAI FERMENTED PORK 160 GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'JELLY GRASS DON MUANG 160 G*10': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'CHAOKUAY DONMUANG OF THE CUBE*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'MILLAC COOKING CREAM1*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.80', 'price_kh': '23,800៛'}},
#  '888 PORK BALL SMALL (N.1) 500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.10', 'price_kh': '16,800៛'}},
#  'C.P P.HOTDOG SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.80', 'price_kh': '23,800៛'}},
#  'MILLAC GOLD CREAM 1 L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.40', 'price_kh': '26,200៛'}},
#  'E&V UNSALT BUTT ROLL82% FAT500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.40', 'price_kh': '30,300៛'}},
#  'TGM Chicken bologna 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.90', 'price_kh': '32,400៛'}},
#  'TGM Arabic wiener hot dog 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$12.50', 'price_kh': '51,300៛'}},
#  'TGM Frankforter 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$10.40', 'price_kh': '42,600៛'}},
#  'TGM Chicken chipolata sau 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$12.30', 'price_kh': '50,400៛'}},
#  'TGM Smoked hot dog4.5inch 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.70', 'price_kh': '31,600៛'}},
#  'TGM Thueringer sausage 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$12.80', 'price_kh': '52,500៛'}},
#  'TGM Pork sausage (COOKED) 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$11.90', 'price_kh': '48,800៛'}},
#  'TGM Smoked hot dog 3inch 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.70', 'price_kh': '31,600៛'}},
#  'TGM Hot dog large 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$10.80', 'price_kh': '44,300៛'}},
#  'TGM WIENER SAUSAGE 1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$14.30', 'price_kh': '58,600៛'}},
#  'TGM Chicken junior sausage1kg x 1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$9.40', 'price_kh': '38,500៛'}},
#  'MEIJI YOGHURT LOW FAT 140G*4': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'NATURAL LOW FAT YOUHURT  500G*8': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$22.40', 'price_kh': '91,800៛'}},
#  ' NATURAL LOW FAT YOUHURT  500G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.90', 'price_kh': '11,900៛'}},
#  'AKM YOGHURT DURIAN 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'AKM YOGHURT PASSION 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'EMBORG SPRAY CREAM 500mlX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.50', 'price_kh': '34,900៛'}},
#  'MEIJI YOGHURT MIXED BERRIES*4': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'MEIJI YOGHURT STRAWBERRY 140G*4': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'MEIJI YOGHURT COCONUT JELLY140G*4': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'AKM YOGHURT MIXFRUIT 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'AKM YOGURT PLAIN 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'AKM YOGURT STRAWBERRY 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'AKM YOGURT ALOE 100GX4PCS': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'TABLELANDS SMART SPREAD 500G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.90', 'price_kh': '16,000៛'}},
#  'PSD SALTED BUTTER 200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'PSD UNSALTED BUTTER 200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'TABLELANDS OLIVE OIL SPREAD 500G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.90', 'price_kh': '16,000៛'}},
#  'KIRISU FARM BARISTA MILK 2L *1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'KIRISU FARM PURE MILK 0% FAT 2L*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'Black grass Jelly 120g 10pcs*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'KIRISU FARM FRESH MILK 830ML*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'F&N MAGNOLIA PAST LOW FAT MILK 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  '888 BEEF BALL SMALL (N.1) 500G*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'MEIJI LOW FAT MILK 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'MEIJI PLAIN MILK 200ML*4': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'MEIJI NON FAT MILK 2L': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'YLY WET FUZU 250G X1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'YLY SLIP FUZU 500GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.70', 'price_kh': '23,400៛'}},
#  'CP.C CHILI SAUSAGE7MM 1KG*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.20', 'price_kh': '25,400៛'}},
#  'CP.C CHEESE 7MM 1KG*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.50', 'price_kh': '30,800៛'}},
#  'Smoky Sausage (1Kg)': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.30', 'price_kh': '34,000៛'}},
#  'Cheese Cocktail (1Kg)': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$10.60', 'price_kh': '43,500៛'}},
#  'BTG HAM SAUSAGE DELUXE1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.60', 'price_kh': '31,200៛'}},
#  'CP JAYOR 1KG*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'BTG SMOKED COCKTAIL SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'BTG SMOKED HOTDOG SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'ARLA FETA CHEESE 200GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'EB EDAM CHEESE PORTION 1X230G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'EB FETA CHEESE 1X200G': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'President Mature cheddar 200g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'President Vintage cheddar 200g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'President Mild cheddar 200g*1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'BTG SMOK C.VIENNA SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'BTG MEAT BALL 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.50', 'price_kh': '30,800៛'}},
#  'EUROLA CHICKEN COCKTAIL 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.30', 'price_kh': '34,000៛'}},
#  'EUROLA CHESS SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$15.70', 'price_kh': '64,400៛'}},
#  'ARLA FETA APETINA CUBES OIL265GX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.40', 'price_kh': '18,000៛'}},
#  'C.P SPICY MINI HOTDOG 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'C.P ROLL 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$6.10', 'price_kh': '25,000៛'}},
#  'C.P C.CHEESE SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.90', 'price_kh': '32,400៛'}},
#  'EUROLA VIENNA SS 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.30', 'price_kh': '34,000៛'}},
#  'EUROLA SMOKED HOTDOG7 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$10.80', 'price_kh': '44,300៛'}},
#  'C.P P.COCKTAIL SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'EUROLA WIENER 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$16.90', 'price_kh': '69,300៛'}},
#  'C.P C.VIENNA SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$5.90', 'price_kh': '24,200៛'}},
#  'EUROLA PORK JUNER SS 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$10.80', 'price_kh': '44,300៛'}},
#  'EUROLA NUEURNBERGER SS 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$15.70', 'price_kh': '64,400៛'}},
#  'C.P C.HOTDOG SAUSAGE COLLAGEN 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$7.50', 'price_kh': '30,800៛'}},
#  'EUROLA SMOKED PORK SS 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$13.70', 'price_kh': '56,200៛'}},
#  'EUROLA BREAKFAST SAUSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.50', 'price_kh': '34,900៛'}},
#  'EUROLA CHICKEN SAUSAGE 3" 1KG': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$9.60', 'price_kh': '39,400៛'}},
#  'DUTCH MILL MIXED FRUIT DRINKING YOGURT 100ML*6': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'EUROLA COCKTAIL SAUSSAGE 1KGX1': {'typeOf': 'Chilled&DairyProducts',
#   'infos': {'price_usd': '$8.30', 'price_kh': '34,000៛'}},
#  'STEAMED MACKEREL 2PCS (SIZE 6-7)': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'Dreid Squid Snow Cherry 250g 1*1': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$5.80', 'price_kh': '23,800៛'}},
#  'CHALITPHONG FISH CAKE 500G': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$4.30', 'price_kh': '17,600៛'}},
#  'FRESH SALMON 5-6 HEAD': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$5.00', 'price_kh': '20,500៛'}},
#  'Dreid Squid Snow Cherry 500g 1*1': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$11.80', 'price_kh': '48,400៛'}},
#  'Dried Yellow Stripe Chilli 500g*1': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$9.70', 'price_kh': '39,800៛'}},
#  'Dried Anchovy Green Pea 500g*1': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$8.00', 'price_kh': '32,800៛'}},
#  'Pacific Oyster 10-15pcs*1': {'typeOf': 'Fish&Seafood',
#   'infos': {'price_usd': '$0.50', 'price_kh': '2,100៛'}},
#  '*SEMI_TSB KETTLE 1.7L#KT-17SH2RKH': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$35.00', 'price_kh': '143,500៛'}},
#  '*SEMI_TSB BLENDER1.5L# BL-60PHRKH': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$42.00', 'price_kh': '172,200៛'}},
#  '*SEMI_DELON. COFFEE MAKER#EC785GY': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$379.00', 'price_kh': '1,553,900៛'}},
#  '*SEMI_SS WASHER FL 9KG#WW90T504DA': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$639.00', 'price_kh': '2,619,900៛'}},
#  '*SEMI_MIDEA WATER DISPEN.#JL1643S': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$389.00', 'price_kh': '1,594,900៛'}},
#  'SAMYANG HOT CHICKEN CHEESE 140GX5': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.70', 'price_kh': '19,300៛'}},
#  'Three lady Mackerel In Tomato Sauce 155gx10': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$6.50', 'price_kh': '26,700៛'}},
#  'CLEAR SHAMPOO 450MLX1 DEEPCLEAN': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'NIKASA Home Pillow 48X74cm *1unit': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'OG FZ WHOLE CLEAM 40-60PC/1KG*1': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'CHERRY PREMIUM - 450G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$12.90', 'price_kh': '52,900៛'}},
#  'BEST FOOD MAGARINE 150GX3': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.00', 'price_kh': '16,400៛'}},
#  'KNORR POWDER CHICKEN 1KG.*1': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$6.80', 'price_kh': '27,900៛'}},
#  'MCCORMICK BROWN SUGAR BBQ SAUCE': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'US F AN CHUCK EYE ROLL SLICE 250': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'FZ GRILL SKEWER MILK PORK X20': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.90', 'price_kh': '20,100៛'}},
#  'PFP CHIKUWA SQUID ROLL240GX4': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'FROZEN STRAWBERRY 200GX5': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'ELECTRIC PAN TEFLON OTTO #SP-314G': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$30.50', 'price_kh': '125,100៛'}},
#  'MIDEA FREEZER#MDRC207FZA01-168': {'typeOf': 'FrozenFood',
#   'infos': {'price_usd': '$289.00', 'price_kh': '1,184,900៛'}},
#  'DRIED SOM RONG FRUIT PACK 1000g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$18.50', 'price_kh': '75,900៛'}},
#  'DRIED SOM RONG FRUIT PACK 500g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$10.00', 'price_kh': '41,000៛'}},
#  'PEELED-SPLIT SOY BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.20', 'price_kh': '4,900៛'}},
#  'THAI GARLIC CLOVES 1 KG.': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'IMPORTED GARLIC CLOVE SMALL 400G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'IMPORT GARLIC CLOVE (L)PACK 1 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'GALA APPLES#120 - 1 MUTATE': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.60', 'price_kh': '2,500៛'}},
#  'Seedless Lime 5kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'FUJI APPLE# 100 - P.6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'SALACCA (INDO) 5 KG.CAT': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.30', 'price_kh': '17,600៛'}},
#  'SHITAKE MUSHROOM 200 G/PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'FRESH CASHEW NUT NO PEEL PACK500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.60', 'price_kh': '31,200៛'}},
#  'KHMER SNGO CHROK SET': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.70', 'price_kh': '2,900៛'}},
#  'RASPBERRY 170 G. - PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.20', 'price_kh': '29,500៛'}},
#  'BLUEBERRY PACK 170G - PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'BABY CHINESE CABBAGE 250g*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.20', 'price_kh': '4,900៛'}},
#  'ZESPRI GOLD KIWI #44 - P.4': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'STRAWBERRY USA/NZ/AU 250G PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'CASHEW NUT hAVE PEEL PACK..280G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.30', 'price_kh': '21,700៛'}},
#  'CASHEW NUT NO PEEL PACK..280G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.30', 'price_kh': '21,700៛'}},
#  'CASHEW NUT HAVE PEEL CAN.250G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.20', 'price_kh': '21,300៛'}},
#  'CASHEW NUT HAVE PEEL CAN.375G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$9.40', 'price_kh': '38,500៛'}},
#  'CASHEW NUT HAVE PEEL CAN.500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$10.90', 'price_kh': '44,700៛'}},
#  'CASHEW NUT NO PEEL CAN.250G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'CASHEW NUT NO PEEL CAN.500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$10.30', 'price_kh': '42,200៛'}},
#  'ENVY APPLE # 30 - P.2': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'BUNA SHIMEJI MUSHROOM 125g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.90', 'price_kh': '3,700៛'}},
#  'WHITE SHIMEJI MUSHROOM 125g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.90', 'price_kh': '3,700៛'}},
#  'MINI TORPIDO WATER MELON 5 PCS': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.80', 'price_kh': '19,700៛'}},
#  'Dried Hawai Pepper pack 200g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'Sun flower seed salty 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'Pumpkin Seed roasted 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'PumpkinSeed mixspices roasted250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'Soy Bean roasted 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'ROASTED ALMOND SLICE 250G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.80', 'price_kh': '19,700៛'}},
#  'HYGIENIC CHINESE KALE PACK 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.40', 'price_kh': '5,700៛'}},
#  'HYGIENIC PURPLEEGGPLANT PACK 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.80', 'price_kh': '3,300៛'}},
#  'ROASTED CASHEW NUT SKIN ON 280G*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.10', 'price_kh': '20,900៛'}},
#  'ROASTED ALMOND 250G *1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'ROASTED CASHEW NUT 280G*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.20', 'price_kh': '21,300៛'}},
#  'SATAY 100G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.70', 'price_kh': '2,900៛'}},
#  'SATAY 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'MIX CHINESE SUOP SET 288 G*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.50', 'price_kh': '26,700៛'}},
#  'Sugar peal seed salty 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'Lotus seed salty  250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'Soy bean mixed spices 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'Tapioca pearl ball pack 500g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.10', 'price_kh': '4,500៛'}},
#  'BLACK SESAME 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$9.50', 'price_kh': '39,000៛'}},
#  'PISTACHIO NUT 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$15.50', 'price_kh': '63,600៛'}},
#  'HYGIENIC SWEET BASIL LEAF\u200b 250G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.70', 'price_kh': '2,900៛'}},
#  'WHITE SESAME 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.70', 'price_kh': '27,500៛'}},
#  "JOB'S TEARS 1Kg": {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.20', 'price_kh': '25,400៛'}},
#  'PEELED-SPLIT SOY BEAN 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.30', 'price_kh': '9,400៛'}},
#  'BLACK BEAN 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.80', 'price_kh': '15,600៛'}},
#  'MUNG BEAN 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'PEANUTS 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'SOYA BEAN 1Kg': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  ' HOT POT BASE-HOT 180G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'NR SICHUAN HOT POT BASE 500G PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.60', 'price_kh': '23,000៛'}},
#  ' Yellow corn pack': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.80', 'price_kh': '3,300៛'}},
#  'MOONDROPS/SWEETSAPPHIREGRAPECTNKG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$13.20', 'price_kh': '54,100៛'}},
#  'YELLOW DRAGON FRUIT CAT 10 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'KEO JIN MANGO 5 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.90', 'price_kh': '11,900៛'}},
#  'SALACCA (SUMALEE) CAT 10 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'PACIFIC ROSE APPLE #80-P.2': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'SM SALTED CUCUMBER PICKLE 200G*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'PACIFIC ROSE APPLE # 80 - PIECE': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.40', 'price_kh': '5,700៛'}},
#  'STRAWBERRY JUMBO 500G PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$12.90', 'price_kh': '52,900៛'}},
#  'GRAN SMITH APPLES# 113 - P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.50', 'price_kh': '26,700៛'}},
#  'PACIFIC ROSE APPLE # 80 - P.6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.80', 'price_kh': '32,000៛'}},
#  'RED DELICIOUS 113 - P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.70', 'price_kh': '27,500៛'}},
#  'ENOKI MUSHROOM 200GX1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.50', 'price_kh': '2,100៛'}},
#  'TAIWANESE VARIETYORANGE-CASE KG.': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'BAMBOO SHOOTSTRIP IN BRINE': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.00', 'price_kh': '12,300៛'}},
#  'SLICED SHITAKE MUSHROOM 500G.X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$9.00', 'price_kh': '36,900៛'}},
#  'CODONOPSIS ROOT 200G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.50', 'price_kh': '30,800៛'}},
#  'VERMICELLI SOUP MIXTURE SET100GX1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'TUMTIM SIAM POMELO': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.90', 'price_kh': '24,200៛'}},
#  'BARLEY 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.60', 'price_kh': '6,600៛'}},
#  'SWEET PLANT 200 G PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.80', 'price_kh': '3,300៛'}},
#  'PEELED INDIAN SHALLOT 1 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.90', 'price_kh': '11,900៛'}},
#  ' ONION PACK 6-7 (KG)': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'ZESPRI GREEN KIWI #78 - P.4': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.30', 'price_kh': '17,600៛'}},
#  'ZESPRI GREEN KIWI #78-P.6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.20', 'price_kh': '25,400៛'}},
#  'Yellow Water Melon KH piece': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  ' RICE CRACKER  PORK FLOSS 130G*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'GALA APPLE# 120 - P.6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'ORANGE MELON 1 PCS': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.50', 'price_kh': '22,600៛'}},
#  'Africa Water melon piece': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'Sonya water Melon piece': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'Kinnare Water Melon piece': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.50', 'price_kh': '10,300៛'}},
#  'SWEET TAMARIN PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.20', 'price_kh': '13,100៛'}},
#  'WHITE SESAME 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'FUJI APPLE #100 - P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'THONG DEE POMELO': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.80', 'price_kh': '11,500៛'}},
#  'GALA APPLES#120 - P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.90', 'price_kh': '24,200៛'}},
#  'LINGZHI MUTSUTAKE 150 G-PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'HAND ORRIGANO POWDER100G.X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'STAR ANISEED GROUND 250G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$9.50', 'price_kh': '39,000៛'}},
#  'DRAGON FRUIT(KH) 10KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.00', 'price_kh': '4,100៛'}},
#  'KAI BANANA Big Hand': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'Seedless Water Melon piece': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.50', 'price_kh': '14,400៛'}},
#  'KAI BANANA P. 6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.80', 'price_kh': '27,900៛'}},
#  'KAO NUMPUANG POMELO': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.00', 'price_kh': '12,300៛'}},
#  'KAI BANANA': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.20', 'price_kh': '4,900៛'}},
#  'IMPORTED GARLIC 400 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.30', 'price_kh': '5,300៛'}},
#  'JAPANESE SWEET POTATO 750G.-PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$9.50', 'price_kh': '39,000៛'}},
#  'THAI GARLIC CLOVES PACK 400 G.': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'INDIAN SHALLOT PACK 1 KG.': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.60', 'price_kh': '10,700៛'}},
#  'PINK LADY # 120 - P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.20', 'price_kh': '21,300៛'}},
#  'ROO MA Picked Garlic 1.8kg*1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.60', 'price_kh': '27,100៛'}},
#  'MHALA CHILLI POWDER 200 G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  'HAND STAR ANISE 500G.X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$18.00', 'price_kh': '73,800៛'}},
#  'CELERY SEEDS GROUND 250G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.10', 'price_kh': '400៛'}},
#  'STRAWBERRY USA/NZ 454 G - PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$11.90', 'price_kh': '48,800៛'}},
#  'IMPORTED GARLIC  PACK 1 KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.00', 'price_kh': '12,300៛'}},
#  'STRAWBERRY KR 250 G.(PACK)': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.70', 'price_kh': '31,600៛'}},
#  'JAZZ APPLE#120-P.10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.20', 'price_kh': '29,500៛'}},
#  'DRIED BLACK MUSHROOM 150 G.X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.60', 'price_kh': '14,800៛'}},
#  "JOB'S TEARS 500 G": {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.10', 'price_kh': '12,700៛'}},
#  'STRIPED DRIED SHITAKE (S) 200 GX1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.60', 'price_kh': '31,200៛'}},
#  'PEELED-SPLIT MUNG BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'MUNG BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'PEELED PEANUTS 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.10', 'price_kh': '8,600៛'}},
#  'SOYA BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.10', 'price_kh': '4,500៛'}},
#  'PEANUTS 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.20', 'price_kh': '9,000៛'}},
#  'RED KIDNEY BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'BLACK BEAN 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'MINI TOPIDO WATER MELON': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.00', 'price_kh': '4,100៛'}},
#  'PATTAVIA  PINEAPPLE': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.70', 'price_kh': '7,000៛'}},
#  'TARD SRI THONG PINEAPPLE': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$0.50', 'price_kh': '2,100៛'}},
#  'ROCKIT APPLE - PACK 4': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'Dried Chinese RedJubjube Big500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.00', 'price_kh': '20,500៛'}},
#  'Dried Chinese RedJubjube Mix500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.00', 'price_kh': '20,500៛'}},
#  'GUSONG Seaweed 1KGx1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.90', 'price_kh': '28,300៛'}},
#  'INDIAN SHALLOT  SACK - KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  'IMPORTED GARLIC CLOVE (L)SACK- KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.40', 'price_kh': '18,000៛'}},
#  'IMPORTED GARLIC BULB (SACK)- KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.70', 'price_kh': '15,200៛'}},
#  'SOUR SOP FRUIT 10KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.40', 'price_kh': '9,800៛'}},
#  'HERBAL SET (BAEL/ROSELLE/DATE)X6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$11.50', 'price_kh': '47,200៛'}},
#  'SULTANA RAISINS 1000 G.X10': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$42.90', 'price_kh': '175,900៛'}},
#  'ROCCO IMPORT POTATO(CATERING) KG': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$3.30', 'price_kh': '13,500៛'}},
#  'Lotus seed mixed spices 250g': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.00', 'price_kh': '8,200៛'}},
#  'MIXED CHERRY TOMATO 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'YELLOW PLUM TOMATO 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'CHERRY TOMATO 500 G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.80', 'price_kh': '7,400៛'}},
#  'LEMON GRASS (ORGANIC) 300G.': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.10', 'price_kh': '4,500៛'}},
#  'BLACKBERRY 1*170G. - PACK': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$7.20', 'price_kh': '29,500៛'}},
#  'DRIED ROSACEOUS SAKURA 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}},
#  'DRIED ROSACEOUS SEEDLESS 500G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$5.20', 'price_kh': '21,300៛'}},
#  'FRIED GARLIC 100 GX6': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$6.50', 'price_kh': '26,700៛'}},
#  'CORIANDER SEEDS 250G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'CUMIN 250G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$2.70', 'price_kh': '11,100៛'}},
#  "SOLOMON'S SEAL PACK 250 G X1": {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$10.20', 'price_kh': '41,800៛'}},
#  'FENNEL 200G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.90', 'price_kh': '7,800៛'}},
#  'DRIED JINDA CHILLI NO STEM 100G': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$1.10', 'price_kh': '4,500៛'}},
#  'PAPRIKA GROUND LOCAL 200G X1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.50', 'price_kh': '18,500៛'}},
#  'HAND PAPRIKA 200 GX1': {'typeOf': 'Fruits&Vegetables',
#   'infos': {'price_usd': '$4.20', 'price_kh': '17,200៛'}}}
