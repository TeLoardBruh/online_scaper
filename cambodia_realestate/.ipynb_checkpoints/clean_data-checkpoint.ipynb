# %%
import os
import json
import re

# %%
def load_data(title):
    with open(title,encoding='utf-8') as f:
        return json.load(f)

# %%
realestate_kh = "./data/realestate_kh_50_pages_2023-05-20.json"
realestate_kh_list = load_data(realestate_kh)

# %%
realestate_kh_list
# Out:
# [{'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$52,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '35',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Preaek Lieb, Chroy Changvar, Phnom Penh',
#   'price': '$290,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Twin'},
#  {'location': ' Sangkat Buon, Sihanoukville, Sihanoukville',
#   'price': '$45,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '35',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$7,500,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '1025',
#   'type': 'Land'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$1,500/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '1593',
#   'type': 'Land'},
#  {'location': ' BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$85,496',
#   'bedrooms': ['1', '6'],
#   'bathrooms': None,
#   'floors': ['39', '1068'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$86,478',
#   'bedrooms': ['1', '3'],
#   'bathrooms': None,
#   'floors': ['32', '136'],
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Tumpun 2, Meanchey, Phnom Penh',
#   'price': '$115,112$80,000SAVE30.50%',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '55',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Platinum Coast',
#   'price': '$60,152',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '35',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Tuek Thla, Sen Sok, Phnom Penh',
#   'price': '$77,164',
#   'bedrooms': ['1', '3'],
#   'bathrooms': None,
#   'floors': ['30', '127'],
#   'lands': None,
#   'type': None},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$110,000',
#   'bedrooms': ['1', '3'],
#   'bathrooms': None,
#   'floors': ['59', '169'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$275,000',
#   'bedrooms': ['1', '3'],
#   'bathrooms': None,
#   'floors': ['78', '196'],
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Srah Chak, Daun Penh, Phnom Penh',
#   'price': '$60,067',
#   'bedrooms': ['1', '2'],
#   'bathrooms': None,
#   'floors': ['37', '91'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' 306 , BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$115,900',
#   'bedrooms': ['1', '2'],
#   'bathrooms': None,
#   'floors': ['43', '1600'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$181,000',
#   'bedrooms': ['2', '3'],
#   'bathrooms': None,
#   'floors': ['65', '153'],
#   'lands': None,
#   'type': None},
#  {'location': '  , Sangkat Buon, Sihanoukville, Sihanoukville',
#   'price': '$73,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': ['32', '66'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' Khmuonh, Sen Sok, Phnom Penh',
#   'price': '$185,000',
#   'bedrooms': ['4', '7'],
#   'bathrooms': None,
#   'floors': ['143', '624'],
#   'lands': None,
#   'type': 'Borey'},
#  {'location': 'LZ Sea View Residences',
#   'price': '$136,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '68',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$68,000',
#   'bedrooms': ['1', '4'],
#   'bathrooms': None,
#   'floors': ['32', '1800'],
#   'lands': None,
#   'type': 'Project'},
#  {'location': ' Komai, Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$183,000',
#   'bedrooms': ['1', '4'],
#   'bathrooms': None,
#   'floors': ['105', '272'],
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'LZ Sea View Residences',
#   'price': '$99,946',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '64',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$225,888',
#   'bedrooms': ['3', '5'],
#   'bathrooms': None,
#   'floors': ['45', '156'],
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Agile Sky Residence',
#   'price': '$115,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '56',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Orkide The Royal Condominium',
#   'price': '$185,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '95',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$73,000',
#   'bedrooms': None,
#   'bathrooms': '1',
#   'floors': '58',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Kak 2, Toul Kork, Phnom Penh',
#   'price': '$2,250,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '789',
#   'type': 'Villa'},
#  {'location': ' Dangkao, Dangkao, Phnom Penh',
#   'price': '$125/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '3213',
#   'type': 'Land'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$65,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '47',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$210,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '81',
#   'lands': '81',
#   'type': 'Flat'},
#  {'location': 'Preaek Ta Sek, Chroy Changvar, Phnom Penh',
#   'price': '$340,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '176',
#   'type': 'Shophouse'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$220,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '104',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sangkat Pir, Sihanoukville, Sihanoukville',
#   'price': '$79,500',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '63',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$772,800',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '2208',
#   'type': 'Land'},
#  {'location': ' Tuol Sangkae 2, Russey Keo, Phnom Penh',
#   'price': '$2,400,000',
#   'bedrooms': '9',
#   'bathrooms': '10',
#   'floors': None,
#   'lands': '1022',
#   'type': 'Villa'},
#  {'location': 'Arakawa Residence',
#   'price': '$65,920$60,000SAVE8.98%',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '46',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Tuol Sangkae 2, Russey Keo, Phnom Penh',
#   'price': '$2,400,000',
#   'bedrooms': '9',
#   'bathrooms': '10',
#   'floors': '945',
#   'lands': '1008',
#   'type': 'Villa'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$195,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '130',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$65,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '62',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Prolit, 7 Makara, Phnom Penh',
#   'price': '$75,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '65',
#   'type': 'Condo'},
#  {'location': ' Boeung Prolit, 7 Makara, Phnom Penh',
#   'price': '$78,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '72',
#   'type': 'Condo'},
#  {'location': 'Chbar Ampov I, Chbar Ampov, Phnom Penh',
#   'price': '$570,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '154',
#   'type': 'Twin'},
#  {'location': 'Chak Angrae Leu, Meanchey, Phnom Penh',
#   'price': '$260,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '108',
#   'type': 'Twin'},
#  {'location': 'Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$2,100,000',
#   'bedrooms': '8',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': '627',
#   'type': 'House'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$13,000,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '2767',
#   'type': 'Land'},
#  {'location': 'Preaek Aeng, Chbar Ampov, Phnom Penh',
#   'price': '$2,800,000',
#   'bedrooms': '6',
#   'bathrooms': '8',
#   'floors': '2250',
#   'lands': '6600',
#   'type': 'Villa'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$1,100,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '240',
#   'lands': '303',
#   'type': 'Villa'},
#  {'location': 'Kakap, Por Sen Chey, Phnom Penh',
#   'price': '$650,000',
#   'bedrooms': '8',
#   'bathrooms': '9',
#   'floors': None,
#   'lands': '280',
#   'type': 'Villa'},
#  {'location': 'Kouk Khleang, Sen Sok, Phnom Penh',
#   'price': '$520,000',
#   'bedrooms': '2',
#   'bathrooms': '11',
#   'floors': '210',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Preaek Luong, Khsach Kandal, Kandal',
#   'price': '$53,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '83',
#   'type': 'House'},
#  {'location': ' Kaoh Rung, Sihanoukville, Sihanoukville',
#   'price': '$150,000',
#   'bedrooms': '2',
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$190,000',
#   'bedrooms': '6',
#   'bathrooms': '8',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Urban Village Phase 2',
#   'price': '$66,000',
#   'bedrooms': None,
#   'bathrooms': '1',
#   'floors': '26',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Samrong Tong, Samraong Tong, Kampong Speu',
#   'price': '$41,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '72',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$545,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': 'Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$320,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$1,239,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$885,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$323,900',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$2,200,000',
#   'bedrooms': '6',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '475',
#   'type': 'Villa'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$500/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': ' Chak Angrae Leu, Meanchey, Phnom Penh',
#   'price': '$125,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '70',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Preaek Lieb, Chroy Changvar, Phnom Penh',
#   'price': '$500,000',
#   'bedrooms': '6',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '90',
#   'type': 'Shophouse'},
#  {'location': 'Boeung Kak 2, Toul Kork, Phnom Penh',
#   'price': '$210,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$1,300,000',
#   'bedrooms': '10',
#   'bathrooms': '9',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$1,500,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$210,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$700,000',
#   'bedrooms': '6',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': ' Kandaek, Prasat Bakong, Siem Reap',
#   'price': '$64,999',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Embassy Central',
#   'price': '$360,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '104',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Toul Svay Prey 1, Chamkarmon, Phnom Penh',
#   'price': '$2,200,000',
#   'bedrooms': '6',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$277,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '77',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Mittapheap, 7 Makara, Phnom Penh',
#   'price': '$150,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$700,000',
#   'bedrooms': '9',
#   'bathrooms': '10',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Kandaek, Prasat Bakong, Siem Reap',
#   'price': '$86,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$270/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': 'Chreav, Siem Reap, Siem Reap',
#   'price': '$135,500',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '108',
#   'lands': '250',
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$180,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$1,260,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$1,500,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': 'Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$330,000',
#   'bedrooms': '2',
#   'bathrooms': '4',
#   'floors': '346',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Toul Tum Poung 2, Chamkarmon, Phnom Penh',
#   'price': '$2,800,000',
#   'bedrooms': '15',
#   'bathrooms': '15',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Srangae, Siem Reap, Siem Reap',
#   'price': '$108,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$299,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '250',
#   'lands': None,
#   'type': 'Flat'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$100,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Prince Huan Yu Center',
#   'price': '$160,000$120,000SAVE25.00%',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '62',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$125,000',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'floors': '99',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Urban Village Phase 2',
#   'price': '$119,500',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '60',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$800,000',
#   'bedrooms': '10',
#   'bathrooms': '10',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$85,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '52',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Boeung Kak 2, Toul Kork, Phnom Penh',
#   'price': '$4,200/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': 'Sangkat Pir, Sihanoukville, Sihanoukville',
#   'price': '$650,000',
#   'bedrooms': '18',
#   'bathrooms': None,
#   'floors': None,
#   'lands': '390',
#   'type': 'Apartment'},
#  {'location': 'Tumnob Tuek, Chamkarmon, Phnom Penh',
#   'price': '$1,300,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Ou Oknha Heng, Prey Nob, Sihanoukville',
#   'price': '$5,340,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '89000',
#   'type': 'Land'},
#  {'location': 'Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$250,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '75',
#   'lands': '168',
#   'type': 'Villa'},
#  {'location': ' Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$154,400',
#   'bedrooms': ['1', '3'],
#   'bathrooms': None,
#   'floors': ['42', '237'],
#   'lands': None,
#   'type': None},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$230,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandaek, Prasat Bakong, Siem Reap',
#   'price': '$90,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Ream, Prey Nob, Sihanoukville',
#   'price': '$8,352,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '55680',
#   'type': 'Land'},
#  {'location': 'BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$78,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '35',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$240,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$950,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '108',
#   'type': 'Villa'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$450,000',
#   'bedrooms': '7',
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kouk Chak, Siem Reap, Siem Reap',
#   'price': '$150,000',
#   'bedrooms': '6',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$310,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '95',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$450,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': '120',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$743,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': '161',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sla Kram, Siem Reap, Siem Reap',
#   'price': '$320,000',
#   'bedrooms': '9',
#   'bathrooms': '9',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$690,000',
#   'bedrooms': '5',
#   'bathrooms': '10',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'DABEST PROPERTIES DABEST PROPERTIES, Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$230,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '94',
#   'lands': '352',
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$160,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '67',
#   'type': 'Shophouse'},
#  {'location': ' Sangkat Sambuor, Siem Reap, Siem Reap',
#   'price': '$78,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Twin'},
#  {'location': 'Rose Apple Square',
#   'price': '$194,010',
#   'bedrooms': '2',
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$250,000',
#   'bedrooms': '7',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': 'Boeung Kak 2, Toul Kork, Phnom Penh',
#   'price': '$3,800,000',
#   'bedrooms': '25',
#   'bathrooms': '28',
#   'floors': '660',
#   'lands': '1076',
#   'type': 'House'},
#  {'location': 'Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$479,900',
#   'bedrooms': '4',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandal',
#   'price': '$93,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '52',
#   'lands': '86',
#   'type': 'House'},
#  {'location': 'Siem Reap, Siem Reap',
#   'price': '$175,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '372',
#   'type': 'House'},
#  {'location': 'Siem Reap',
#   'price': '$69,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '93',
#   'lands': '154',
#   'type': 'House'},
#  {'location': 'Tumnob Tuek, Chamkarmon, Phnom Penh',
#   'price': '$72,500',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '59',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Siem Reap, Siem Reap',
#   'price': '$120,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '75',
#   'lands': '153',
#   'type': 'House'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$198,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$68,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Sangkat Buon, Sihanoukville, Sihanoukville',
#   'price': '$259,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$1,200,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$100,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Snaor, Por Sen Chey, Phnom Penh',
#   'price': '$65,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$75,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$320,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '207',
#   'type': 'Villa'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$135,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$460,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$139,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '240',
#   'type': 'Villa'},
#  {'location': 'Sangkat Sambuor, Siem Reap, Siem Reap',
#   'price': '$980,000',
#   'bedrooms': '7',
#   'bathrooms': '7',
#   'floors': '400',
#   'lands': '5724',
#   'type': 'Villa'},
#  {'location': 'DABEST PROPERTIES, Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$220,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': '422',
#   'type': 'Villa'},
#  {'location': 'Dabest Properties, Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$1,950,000',
#   'bedrooms': '6',
#   'bathrooms': '7',
#   'floors': '548',
#   'lands': '2100',
#   'type': 'Villa'},
#  {'location': 'Kampong Samnanh, Ta Khmau, Kandal',
#   'price': '$65,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Kravan, Chbar Mon, Kampong Speu',
#   'price': '$45,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Bak Kaeng, Chroy Changvar, Phnom Penh',
#   'price': '$147,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandal',
#   'price': '$39,100',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '36',
#   'lands': '247',
#   'type': 'House'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$44,500',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$650,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': '252',
#   'lands': '1506',
#   'type': 'House'},
#  {'location': 'Chreav, Siem Reap, Siem Reap',
#   'price': '$110,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$1,250,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chbar Ampov II, Chbar Ampov, Phnom Penh',
#   'price': '$210,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Kampong Speu',
#   'price': '$250,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': '150',
#   'lands': '300',
#   'type': 'House'},
#  {'location': 'Preaek Aeng, Chbar Ampov, Phnom Penh',
#   'price': '$129,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '50',
#   'lands': '84',
#   'type': 'House'},
#  {'location': 'Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$330,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chomkar Somraong, Battambang, Battambang',
#   'price': '$51,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Siem Reap, Siem Reap, Siem Reap',
#   'price': '$95,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Ta Khmau, Kandal',
#   'price': '$148,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '136',
#   'lands': '200',
#   'type': 'House'},
#  {'location': 'Battambang, Battambang',
#   'price': '$55,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandal',
#   'price': '$28,500',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Meanchey, Phnom Penh',
#   'price': '$22,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Ta Khmau, Kandal',
#   'price': '$50,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '90',
#   'lands': '112',
#   'type': 'House'},
#  {'location': 'Baek Chan, Angk Snuol, Kandal',
#   'price': '$185,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '192',
#   'type': 'House'},
#  {'location': 'Battambang',
#   'price': '$33,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Snaor, Por Sen Chey, Phnom Penh',
#   'price': '$95,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': '80',
#   'lands': '180',
#   'type': 'House'},
#  {'location': 'Krang Mkak, Angk Snuol, Kandal',
#   'price': '$78,500',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Flat'},
#  {'location': 'Chreav, Siem Reap, Siem Reap',
#   'price': '$495,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '314',
#   'lands': '615',
#   'type': 'Villa'},
#  {'location': 'Battambang, Battambang',
#   'price': '$70,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandal',
#   'price': '$135,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '1350',
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$119,999',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '74',
#   'type': 'House'},
#  {'location': '',
#   'price': '$150,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '9800',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandaek, Prasat Bakong, Siem Reap',
#   'price': '$130,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$75,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$169,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$115,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '6700',
#   'lands': '8600',
#   'type': 'House'},
#  {'location': 'Russey Keo, Phnom Penh',
#   'price': '$650,000',
#   'bedrooms': '6',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Samraong Kraom, Por Sen Chey, Phnom Penh',
#   'price': '$115,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Villa'},
#  {'location': '',
#   'price': '$218,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': '169',
#   'type': 'House'},
#  {'location': '',
#   'price': '$120,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '7000',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$89,999',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kep, Kep',
#   'price': '$1,000,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '589',
#   'lands': '818',
#   'type': 'House'},
#  {'location': 'Kakaoh, Santuk, Kampong Thom',
#   'price': '$55,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$83,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Odongk, Kampong Speu',
#   'price': '$36,000',
#   'bedrooms': '2',
#   'bathrooms': None,
#   'floors': '48',
#   'lands': '777',
#   'type': 'House'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$545,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '270',
#   'lands': '425',
#   'type': 'Villa'},
#  {'location': 'Nitean, Basedth, Kampong Speu',
#   'price': '$3,412,225',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '136489',
#   'type': 'Land'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$120,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '190',
#   'lands': '607',
#   'type': 'House'},
#  {'location': 'Chroy Changvar, Phnom Penh',
#   'price': '$74,000',
#   'bedrooms': '5',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kampong Trach, Kampot',
#   'price': '$265,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$158,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '16800',
#   'lands': '27000',
#   'type': 'House'},
#  {'location': 'Sralau, Baray, Kampong Thom',
#   'price': '$85,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '48',
#   'lands': '220',
#   'type': 'House'},
#  {'location': 'Chaom Chau 2, Por Sen Chey, Phnom Penh',
#   'price': '$67,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': 'Meanchey, Phnom Penh',
#   'price': '$150,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$280,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$180,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '96',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$135,000',
#   'bedrooms': '5',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Flat'},
#  {'location': '',
#   'price': '$195,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': '',
#   'price': '$135,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': '12800',
#   'lands': '25200',
#   'type': 'House'},
#  {'location': 'Takeo',
#   'price': '$43,888',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '82',
#   'lands': '290',
#   'type': 'House'},
#  {'location': 'Chreav, Siem Reap, Siem Reap',
#   'price': '$225,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Tuol Sangke, Russey Keo, Phnom Penh',
#   'price': '$93,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$95,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': '6100',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$650,000',
#   'bedrooms': '24',
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Flat'},
#  {'location': 'Eastland Hotel and Apartment',
#   'price': '$85,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '38',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Chaom Chau 1, Por Sen Chey, Phnom Penh',
#   'price': '$97,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kampong Roteh, Stueng Saen, Kampong Thom',
#   'price': '$280,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': '42',
#   'lands': '408',
#   'type': 'House'},
#  {'location': 'Sangkat Buon, Sihanoukville, Sihanoukville',
#   'price': '$350,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$79,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '56',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Koh Kong',
#   'price': '$55,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '60',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Poipet, Poipet, Banteay Meanchey',
#   'price': '$71,000',
#   'bedrooms': '5',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Russey Keo, Phnom Penh',
#   'price': '$92,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chaom Chau 3, Por Sen Chey, Phnom Penh',
#   'price': '$175,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '58',
#   'lands': '118',
#   'type': 'House'},
#  {'location': 'Spean Thma, Dangkao, Phnom Penh',
#   'price': '$49,999',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$375,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '218',
#   'type': 'House'},
#  {'location': 'Roka Knong, Doun Kaev, Takeo',
#   'price': '$300,000',
#   'bedrooms': '12',
#   'bathrooms': '12',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Salang, Toul Kork, Phnom Penh',
#   'price': '$650,000',
#   'bedrooms': '7',
#   'bathrooms': '7',
#   'floors': '176',
#   'lands': '336',
#   'type': 'House'},
#  {'location': 'Dangkao, Dangkao, Phnom Penh',
#   'price': '$160,000',
#   'bedrooms': '5',
#   'bathrooms': '5',
#   'floors': '64',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandaek, Prasat Bakong, Siem Reap',
#   'price': '$135,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': "Tuek L'ak 3, Toul Kork, Phnom Penh",
#   'price': '$183,880',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '60',
#   'lands': '100',
#   'type': 'House'},
#  {'location': 'Siem Reap',
#   'price': '$185,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Siem Reap, Siem Reap',
#   'price': '$300,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Siem Reap, Siem Reap',
#   'price': '$180,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '600',
#   'type': 'House'},
#  {'location': 'Kampot, Kampot',
#   'price': '$230,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$55,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kandal',
#   'price': '$56,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$65,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '76',
#   'type': 'House'},
#  {'location': 'Krang Thnong, Sen Sok, Phnom Penh',
#   'price': '$47,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Dangkao, Dangkao, Phnom Penh',
#   'price': '$99,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '64',
#   'lands': '86',
#   'type': 'House'},
#  {'location': 'Chaom Chau 3, Por Sen Chey, Phnom Penh',
#   'price': '$74,000',
#   'bedrooms': '4',
#   'bathrooms': '3',
#   'floors': '85',
#   'lands': '168',
#   'type': 'House'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$495,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Tuek Thla, Sen Sok, Phnom Penh',
#   'price': '$335,000',
#   'bedrooms': '6',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '125',
#   'type': 'House'},
#  {'location': 'BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$200,000$183,000SAVE8.50%',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '58',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Veal Sbov, Chbar Ampov, Phnom Penh',
#   'price': '$195,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '301',
#   'type': 'Land'},
#  {'location': 'Sla Kram, Siem Reap, Siem Reap',
#   'price': '$125,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '88',
#   'lands': '161',
#   'type': 'House'},
#  {'location': 'Ta Khmau, Kandal',
#   'price': '$72,000',
#   'bedrooms': '5',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Kak 2, Toul Kork, Phnom Penh',
#   'price': '$269,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '158',
#   'type': 'House'},
#  {'location': 'Kakap, Por Sen Chey, Phnom Penh',
#   'price': '$78,200',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Stueng Mean chey 3, Meanchey, Phnom Penh',
#   'price': '$85,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Samraong Kraom, Por Sen Chey, Phnom Penh',
#   'price': '$439,999',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Preaek Pnov, Prek Pnov, Phnom Penh',
#   'price': '$55,000',
#   'bedrooms': '1',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Russey Keo, Russey Keo, Phnom Penh',
#   'price': '$48,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Meanchey, Phnom Penh',
#   'price': '$140,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Dangkao, Phnom Penh',
#   'price': '$96,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kamboul, Por Sen Chey, Phnom Penh',
#   'price': '$120,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Anlong Vil, Sangkae, Battambang',
#   'price': '$45,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$270,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '153',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Stueng Mean chey, Meanchey, Phnom Penh',
#   'price': '$85,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Preaek Anhchanh, Mukh Kampul, Kandal',
#   'price': '$66,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '50',
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kakab 1, Por Sen Chey, Phnom Penh',
#   'price': '$155,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Preaek Kampues, Dangkao, Phnom Penh',
#   'price': '$50,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Meanchey, Phnom Penh',
#   'price': '$90,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Kamboul, Por Sen Chey, Phnom Penh',
#   'price': '$54,500',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Dangkao, Dangkao, Phnom Penh',
#   'price': '$93,555',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '92',
#   'type': 'House'},
#  {'location': 'Kandal Stueng, Kandal',
#   'price': '$105,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '60',
#   'lands': '203',
#   'type': 'House'},
#  {'location': 'Kampong Chhnang, Kampong Chhnang',
#   'price': '$98,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Dangkao, Phnom Penh',
#   'price': '$169,000',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Meanchey, Phnom Penh',
#   'price': '$83,500',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$52,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Ta Khmau, Kandal',
#   'price': '$25,900',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': "Tuek L'ak 2, Toul Kork, Phnom Penh",
#   'price': '$600,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Siem Reap',
#   'price': '$65,000',
#   'bedrooms': '1',
#   'bathrooms': '2',
#   'floors': '65',
#   'lands': '252',
#   'type': 'House'},
#  {'location': 'Krang Thnong, Sen Sok, Phnom Penh',
#   'price': '$98,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Tuol Sangke, Russey Keo, Phnom Penh',
#   'price': '$115,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Sihanoukville, Sihanoukville',
#   'price': '$220,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': '80',
#   'lands': '246',
#   'type': 'House'},
#  {'location': 'Preaek Kampues, Dangkao, Phnom Penh',
#   'price': '$140,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '432',
#   'type': 'Land'},
#  {'location': ' Chreav, Siem Reap, Siem Reap',
#   'price': '$495,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$655,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '960',
#   'type': 'Land'},
#  {'location': 'Khmuonh, Sen Sok, Phnom Penh',
#   'price': '$62,000',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': '105',
#   'type': 'House'},
#  {'location': 'Krang Thnong, Sen Sok, Phnom Penh',
#   'price': '$110,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '58',
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$123,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '88',
#   'type': 'House'},
#  {'location': 'Krang Thnong, Sen Sok, Phnom Penh',
#   'price': '$85,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': '66',
#   'lands': '92',
#   'type': 'Apartment'},
#  {'location': 'Kamboul, Por Sen Chey, Phnom Penh',
#   'price': '$63,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '49',
#   'type': 'House'},
#  {'location': 'Boeung Salang, Toul Kork, Phnom Penh',
#   'price': '$1,200,000',
#   'bedrooms': '5',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$95,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '48',
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$77,500',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '64',
#   'type': 'House'},
#  {'location': "Setbou, S'ang, Kandal",
#   'price': '$53,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '84',
#   'type': 'House'},
#  {'location': 'Prey Sa, Dangkao, Phnom Penh',
#   'price': '$169,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Preaek Kampues, Dangkao, Phnom Penh',
#   'price': '$108,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '86',
#   'type': 'House'},
#  {'location': 'Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$155,000',
#   'bedrooms': '5',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': '64',
#   'type': 'House'},
#  {'location': 'Dangkao, Phnom Penh',
#   'price': '$138,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '109',
#   'type': 'House'},
#  {'location': 'Khmuonh, Sen Sok, Phnom Penh',
#   'price': '$225,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '64',
#   'type': 'House'},
#  {'location': 'Boeung Tumpun 1, Meanchey, Phnom Penh',
#   'price': '$137,000',
#   'bedrooms': '5',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '86',
#   'type': 'House'},
#  {'location': 'Khmuonh, Sen Sok, Phnom Penh',
#   'price': '$240,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '66',
#   'type': 'House'},
#  {'location': 'Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$220,000',
#   'bedrooms': '5',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '67',
#   'type': 'House'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$165,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '133',
#   'type': 'House'},
#  {'location': 'Kamboul, Por Sen Chey, Phnom Penh',
#   'price': '$75,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Stueng Mean chey 3, Meanchey, Phnom Penh',
#   'price': '$58,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '76',
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$120,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '171',
#   'type': 'Land'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$60,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Svay Toea, Svay Rieng, Svay Rieng',
#   'price': '$389,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '1362',
#   'type': 'House'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$300,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': None,
#   'type': 'Twin'},
#  {'location': 'Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$710,000',
#   'bedrooms': '6',
#   'bathrooms': '5',
#   'floors': '168',
#   'lands': '368',
#   'type': 'Villa'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$293,700',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '72',
#   'lands': '169',
#   'type': 'Twin'},
#  {'location': 'Chak Angrae Leu, Meanchey, Phnom Penh',
#   'price': '$105,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Flat'},
#  {'location': 'Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$140,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': '62',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Ta Khmao, Ta Khmau, Kandal',
#   'price': '$65,000',
#   'bedrooms': '2',
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Link'},
# ...
#   'floors': None,
#   'lands': '90',
#   'type': 'Flat'},
#  {'location': ' Preaek Lieb, Chroy Changvar, Phnom Penh',
#   'price': '$330,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '234',
#   'lands': '178',
#   'type': 'Twin'},
#  {'location': ' Preaek Lieb, Chroy Changvar, Phnom Penh',
#   'price': '$690,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': '468',
#   'lands': '420',
#   'type': 'Villa'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$380,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '120',
#   'type': 'Shophouse'},
#  {'location': 'Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$3,500,000',
#   'bedrooms': '15',
#   'bathrooms': '15',
#   'floors': None,
#   'lands': '729',
#   'type': 'Villa'},
#  {'location': ' Mittapheap, 7 Makara, Phnom Penh',
#   'price': '$180,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Olympic, Chamkarmon, Phnom Penh',
#   'price': '$50,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '45',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$600,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': '333',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Preaek Lieb, Chroy Changvar, Phnom Penh',
#   'price': '$95,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '71',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Chak Angrae Kraom, Meanchey, Phnom Penh',
#   'price': '$9,504,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '3520',
#   'type': 'Land'},
#  {'location': ' Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$750,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': ' Sangkat Bei, Sihanoukville, Sihanoukville',
#   'price': '$1,400,000',
#   'bedrooms': '24',
#   'bathrooms': '24',
#   'floors': None,
#   'lands': '263',
#   'type': 'Apartment'},
#  {'location': 'Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$400,000',
#   'bedrooms': '5',
#   'bathrooms': '7',
#   'floors': '270',
#   'lands': '250',
#   'type': 'Twin'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$303,000',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'floors': '119',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$130,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$129,000',
#   'bedrooms': '6',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$190,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': '152',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$390,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Twin'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$280,000',
#   'bedrooms': '5',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Phsar Kandal II, Daun Penh, Phnom Penh',
#   'price': '$250,000',
#   'bedrooms': '5',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Flat'},
#  {'location': ' Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$320,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '157',
#   'type': 'Twin'},
#  {'location': 'Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$1,500,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': '74',
#   'type': 'Shophouse'},
#  {'location': 'Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$2,800,000',
#   'bedrooms': '6',
#   'bathrooms': '11',
#   'floors': None,
#   'lands': '126',
#   'type': 'House'},
#  {'location': ' Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$1,500,000',
#   'bedrooms': '6',
#   'bathrooms': '8',
#   'floors': None,
#   'lands': '438',
#   'type': 'Villa'},
#  {'location': ' Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$350,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '157',
#   'type': 'Twin'},
#  {'location': ' Phnom Penh Thmey, Sen Sok, Phnom Penh',
#   'price': '$300,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '157',
#   'type': 'Twin'},
#  {'location': 'Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$160,315',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '75',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': 'Toul Svay Prey 2, Chamkarmon, Phnom Penh',
#   'price': '$2,200,000',
#   'bedrooms': '6',
#   'bathrooms': '7',
#   'floors': None,
#   'lands': '475',
#   'type': 'Villa'},
#  {'location': ' Phsar Kandal I, Daun Penh, Phnom Penh',
#   'price': '$200,000',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'floors': '70',
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Dangkao, Dangkao, Phnom Penh',
#   'price': '$169,000',
#   'bedrooms': '3',
#   'bathrooms': '5',
#   'floors': '227',
#   'lands': '99',
#   'type': 'Shophouse'},
#  {'location': 'Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$550,604',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': '288',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Dangkao, Dangkao, Phnom Penh',
#   'price': '$249,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '287',
#   'lands': '185',
#   'type': 'Twin'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$130,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '53',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$634,950',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': 'Toul Svay Prey 1, Chamkarmon, Phnom Penh',
#   'price': '$2,000,000',
#   'bedrooms': None,
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$190,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$790,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '107',
#   'type': 'Shophouse'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$850,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': ' Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$76,200',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '40',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$68,200',
#   'bedrooms': '1',
#   'bathrooms': None,
#   'floors': '43',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Boeung Tumpun, Meanchey, Phnom Penh',
#   'price': '$550,000',
#   'bedrooms': '10',
#   'bathrooms': '11',
#   'floors': None,
#   'lands': '87',
#   'type': 'Shophouse'},
#  {'location': 'BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$150,693',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '72',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Anlong Romiet, Kandal Stueng, Kandal',
#   'price': '$69,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '200',
#   'type': 'House'},
#  {'location': 'BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$103,730',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '57',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Nirouth, Chbar Ampov, Phnom Penh',
#   'price': '$255,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '68',
#   'type': 'Shophouse'},
#  {'location': ' Kampong Kraeng, Tuek Chhou, Kampot',
#   'price': '$1,800,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '6645',
#   'type': 'Land'},
#  {'location': ' Chak Angrae Leu, Meanchey, Phnom Penh',
#   'price': '$480,000',
#   'bedrooms': '4',
#   'bathrooms': '4',
#   'floors': '260',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'Chakto Mukh, Daun Penh, Phnom Penh',
#   'price': '$42,000',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'floors': '88',
#   'lands': None,
#   'type': 'Flat'},
#  {'location': 'Phsar Thmei I, Daun Penh, Phnom Penh',
#   'price': '$850,000',
#   'bedrooms': '6',
#   'bathrooms': '8',
#   'floors': '113',
#   'lands': None,
#   'type': 'Shophouse'},
#  {'location': ' Tuol Sangkae 1, Russey Keo, Phnom Penh',
#   'price': '$82,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '67',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': 'BKK 2, Chamkarmon, Phnom Penh',
#   'price': '$53,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '35',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$140,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '60',
#   'type': 'Link'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$450/m²',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': ' Chroy Changvar, Chroy Changvar, Phnom Penh',
#   'price': '$8,455,200',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '3523',
#   'type': 'Villa'},
#  {'location': 'Chaom Chau, Por Sen Chey, Phnom Penh',
#   'price': '$2,900,000',
#   'bedrooms': '7',
#   'bathrooms': '10',
#   'floors': '200',
#   'lands': '844',
#   'type': 'Villa'},
#  {'location': '214 , Boeng Reang, Daun Penh, Phnom Penh',
#   'price': '$95,000',
#   'bedrooms': None,
#   'bathrooms': '1',
#   'floors': '38',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$450',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': None,
#   'type': 'Apartment'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$800,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$409,217',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$150,172',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Tonle Bassac, Chamkarmon, Phnom Penh',
#   'price': '$442,300',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Sala Kamraeuk, Siem Reap, Siem Reap',
#   'price': '$1,160,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Land'},
#  {'location': 'Boeung Trabek, Chamkarmon, Phnom Penh',
#   'price': '$8,496,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '708',
#   'type': 'Land'},
#  {'location': 'Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$612,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '3060',
#   'type': 'Land'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$917,000',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'floors': None,
#   'lands': '131',
#   'type': 'Apartment'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$1,500,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': '108',
#   'lands': '141',
#   'type': 'Shophouse'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$800,000',
#   'bedrooms': '4',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '118',
#   'type': 'Shophouse'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$650,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '100',
#   'type': 'Shophouse'},
#  {'location': 'Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$580,000',
#   'bedrooms': '3',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '68',
#   'type': 'Flat'},
#  {'location': 'Phsar Chas, Daun Penh, Phnom Penh',
#   'price': '$450,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': '151',
#   'lands': '151',
#   'type': 'Shophouse'},
#  {'location': ' BKK 1, Chamkarmon, Phnom Penh',
#   'price': '$125,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': '89',
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Chreav, Siem Reap, Siem Reap',
#   'price': '$150,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': None,
#   'type': 'House'},
#  {'location': 'Chay Stueng Chay Stueng, Kampong Seila, Kampong Seila, Sihanoukville',
#   'price': '$292,050',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '1239',
#   'type': 'Villa'},
#  {'location': ' Chey Chumneah, Daun Penh, Phnom Penh',
#   'price': '$700,000',
#   'bedrooms': '5',
#   'bathrooms': '3',
#   'floors': '400',
#   'lands': '100',
#   'type': 'Flat'},
#  {'location': 'Tumnob Tuek, Chamkarmon, Phnom Penh',
#   'price': '$1,400,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '280',
#   'type': 'Land'},
#  {'location': ' BKK 3, Chamkarmon, Phnom Penh',
#   'price': '$450',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': None,
#   'type': 'Condo'},
#  {'location': ' Kouk Roka, Prek Pnov, Phnom Penh',
#   'price': '$50,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '49',
#   'type': 'Flat'},
#  {'location': 'Toul Tum Poung 1, Chamkarmon, Phnom Penh',
#   'price': '$1,500,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '442',
#   'type': 'Land'},
#  {'location': ' Tumnob Tuek, Chamkarmon, Phnom Penh',
#   'price': '$230,000',
#   'bedrooms': '3',
#   'bathrooms': '4',
#   'floors': None,
#   'lands': '72',
#   'type': 'Shophouse'},
#  {'location': ' Pong Tuek, Dangkao, Phnom Penh',
#   'price': '$90,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '79',
#   'type': 'Flat'},
#  {'location': 'Stueng Mean chey 1, Meanchey, Phnom Penh',
#   'price': '$1,200,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '1804',
#   'type': 'Land'},
#  {'location': ' Chrang Chamres 2, Russey Keo, Phnom Penh',
#   'price': '$280,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '92',
#   'type': 'Shophouse'},
#  {'location': ' Krang Thnong, Sen Sok, Phnom Penh',
#   'price': '$110,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '90',
#   'type': 'Link'},
#  {'location': ' Boeung Kak 1, Toul Kork, Phnom Penh',
#   'price': '$260,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '87',
#   'type': 'Flat'},
#  {'location': ' Veal Vong, 7 Makara, Phnom Penh',
#   'price': '$280,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '88',
#   'type': 'Shophouse'},
#  {'location': ' Tuol Sangke, Russey Keo, Phnom Penh',
#   'price': '$250,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '148',
#   'type': 'Flat'},
#  {'location': "Tuek L'ak 1, Toul Kork, Phnom Penh",
#   'price': '$260,000',
#   'bedrooms': None,
#   'bathrooms': None,
#   'floors': None,
#   'lands': '271',
#   'type': 'Land'},
#  {'location': ' Chaom Chau 3, Por Sen Chey, Phnom Penh',
#   'price': '$98,000',
#   'bedrooms': '3',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '98',
#   'type': 'Link'},
#  {'location': ' Kakab 1, Por Sen Chey, Phnom Penh',
#   'price': '$120,000',
#   'bedrooms': '5',
#   'bathrooms': '6',
#   'floors': None,
#   'lands': '102',
#   'type': 'Flat'},
#  {'location': ' Ta Khmao, Ta Khmau, Kandal',
#   'price': '$47,000',
#   'bedrooms': '2',
#   'bathrooms': '3',
#   'floors': None,
#   'lands': '77',
#   'type': 'Flat'},
#  {'location': ' Khmuonh, Sen Sok, Phnom Penh',
#   'price': '$255,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': '160',
#   'type': 'Twin'},
#  {'location': ' Svay Dankum, Siem Reap, Siem Reap',
#   'price': '$1,054,000',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'floors': None,
#   'lands': '1054',
#   'type': 'House'},
#  {'location': 'Phsar Thmei III, Daun Penh, Phnom Penh',
#   'price': '$700,000',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'floors': None,
#   'lands': None,
#   'type': 'Shophouse'}]

# %%
cambodia_province = '''Banteay Meanchey|Battambang|Kampong Cham|Kampong Chhnang|Kampong Speu|Kampong Thom|Kampot|Kandal|Koh Kong
|Kratié|Mondulkiri|Phnom Penh|Preah Vihear|Prey Veng|Pursat|Ratanakiri|Siem Reap|Preah Sihanouk|Sihanoukville|Stung Treng|Svay Rieng|Takéo|Oddar Meanchey
|Kep|Pailin|Tboung Khmum'''

# %%
for i in realestate_kh_list:
    if re.search(cambodia_province, str(i['location']),re.IGNORECASE):
        i['location'] = re.search(cambodia_province, str(i['location']),re.IGNORECASE).group()
    else:
        # print('========= '+str(i['location'])+' =========')
        if i['location']:
            print('========= '+str(i['location'])+' =========')
            
# realestate_kh_list
# Out:
# ========= Platinum Coast =========
# ========= LZ Sea View Residences =========
# ========= LZ Sea View Residences =========
# ========= Agile Sky Residence =========
# ========= Orkide The Royal Condominium =========
# ========= Arakawa Residence =========
# ========= Urban Village Phase 2 =========
# ========= Embassy Central =========
# ========= Prince Huan Yu Center =========
# ========= Urban Village Phase 2 =========
# ========= Rose Apple Square =========
# ========= Takeo =========
# ========= Eastland Hotel and Apartment =========
# ========= Koh Kong =========
# ========= Roka Knong, Doun Kaev, Takeo =========
# ========= Urban Village Phase 2 =========
# ========= Borey Morgan Champs-Élysées =========
# ========= Borey Morgan Champs-Élysées =========
# ========= Borey Morgan Champs-Élysées =========
# ========= Borey Morgan Champs-Élysées =========
# ========= Borey Morgan Champs-Élysées =========
# ========= Skylar by Meridian =========
# ========= Urban Village Phase 1 =========
# ========= Royal Park Condo =========
# ========= Urban Village Phase 1 =========
# ========= CASA by Meridian =========
# ========= CASA by Meridian =========
# ========= Royal Park Condo =========
# ========= Royal Park Condo =========
# ========= Royal Park Condo =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= De Castle Diamond Condominium =========
# ========= Urban Village Phase 1 =========
# ========= Kronhoung Saen Chey, Snuol, Kratie =========
# ========= Otdam Soriya, Tram Kak, Takeo =========
# ========= Urban Village Phase 1 =========
# ========= Kracheh, Kratie =========
# ========= 76 ផ្លូវជាតិ៧៦, Pir Thnu, Snuol, Kratie =========
# =========  Pak Khlang, Mondol Seima, Koh Kong =========
# ========= Kaoh Sdach, Kiri Sakor, Koh Kong =========

# %%
def save_data(title,data):
    with open(title, "w",encoding='utf-8') as outfile:
        json.dump(data, outfile, ensure_ascii=False, indent=3)

# %%
realestate_kh = "./realestate_kh.json"
save_data(realestate_kh,realestate_kh_list)

# %%
realestate_kh_list
# Out:
# [{'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': 'Villa for Sale in Siem Reap-Kon Deak Borey Tourism siem reap',
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$130,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Land area: 240m²</span>]'},
#  {'name': 'Land for Sale in\u200b Krong Siem Reap-Sangkat Chreav ',
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$59,150',
#   'infos': '[<span class="label">Land area: 455m²</span>]'},
#  {'name': 'Spacious 2Bedroom Condo For Sale in Olympia City',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$220,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 122m²</span>, <span class="label">Facing: E/S</span>]'},
#  {'name': 'DABEST PROPERTIES: Luxuxry Villa for Sale in Siem Reap- Sala Kamreuk',
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$550,000',
#   'infos': '[<span class="label">Bedrooms: 6</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 3</span>, <span class="label">Floor area: 317m²</span>, <span class="label">Land area: 800m²</span>]'},
#  {'name': 'Le Condé BKK1',
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$139,895',
#   'infos': '[<span class="label">Total units: 1080</span>, <span class="label">Unit types: Condo, Studio, Condo, Retail</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 39 to 167m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">39m²</span>, <span class="label">7</span>, <span class="label">N</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">61m²</span>, <span class="label">23</span>, <span class="label">S</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">61m²</span>, <span class="label">7</span>, <span class="label">N</span>]'},
#  {'name': 'Luxury Penthouse | 3 Floors | 4 Master Bedrooms | Private Cinema, Swimming Pool, Gym, Salon',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$3,500,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 1054m²</span>, <span class="label">Floor level: 32</span>]'},
#  {'name': 'Orkide The Royal Condominium',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$73,489',
#   'infos': '[<span class="label">Total units: 1999</span>, <span class="label">Unit types: Apartment, Condo, Link House, Villa, Condo, Shophouse</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 30 to 127m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">30m²</span>, <span class="label">8</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">48m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">63m²</span>]'},
#  {'name': 'Diamond Bay Garden',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$99,000',
#   'infos': '[<span class="label">Total units: 591</span>, <span class="label">Unit types: Condo, Shophouse, Studio</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 59 to 169m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">62m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">60m²</span>, <span class="label">2</span>, <span class="label">1</span>, <span class="label">75m²</span>]'},
#  {'name': 'Odom Living',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$275,000',
#   'infos': '[<span class="label">Total units: 138</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 78 to 196m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">78m²</span>, <span class="label">N/E</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">80m²</span>, <span class="label">N/E</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">111m²</span>, <span class="label">S/W</span>]'},
#  {'name': 'DABEST PROPERTIES: Modern Villa for Sale in Siem Reap-Sala Kamreuk',
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$590,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 200m²</span>, <span class="label">Land area: 1150m²</span>]'},
#  {'name': 'DABEST PROPERTIES: Villa for Sale in Siem Reap - Borey ',
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$175,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 250m²</span>]'},
#  {'name': 'Beautiful Luxury Villa for Sale',
#   'location': 'Kandal',
#   'category': 'Villa',
#   'price': '$1,450,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 7</span>]'},
#  {'name': '34th Floor 3 Bedroom For Sale in The Bridge, Phnom Penh',
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$195,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor level: 34</span>]'},
#  {'name': '2 Bedroom Condo For Sale - Embassy Residences, Phnom Penh',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$380,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 153m²</span>, <span class="label">Land area: 153m²</span>, <span class="label">Floor level: 11</span>]'},
#  {'name': '4 Bedroom Villa For Sale - Ta Khmau, Kandal',
#   'location': 'Kandal',
#   'category': 'Villa',
#   'price': '$650,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 320m²</span>, <span class="label">Land area: 883m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': '22320 Sqm Land For Sale - Sambour, Siem Reap',
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$85/m²',
#   'infos': '[<span class="label">Land area: 22320m²</span>]'},
#  {'name': "This prime development site is located in Cambodia's tourist town of Siem Reap, fronting the city's main highway along National Road 6, close to the city centre, Angkor Wat and the International Airport.",
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$30,000,000',
#   'infos': '[<span class="label">Land area: 40512m²</span>]'},
#  {'name': 'New 4-bed apartment for sale in Phsar Chas, Daun Penh, Phnom Penh.',
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$280,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Floor area: 230m²</span>]'},
#  {'name': 'New Borey Project Prince One Tropica | Single Villa for Sale in Sen Sok Area',
#   'location': 'New Borey Project Prince One Tropica | Single Villa for Sale in Sen Sok AreaFeaturedFor saleLuxury PropertyVilla$690,000  Prince One Tropica\ue920 Bedrooms: 66\ue91f Bathrooms: 88\ue90d Car spaces: 33\ue94a Floor area: 340m²340m²\ue93f Land area: 200m²200m²\ue933 Facing: SS\ue923 High Return Yield\ue923 Brand Developer\ue923 High Appreciation Value Updated: 1\xa0week agoPrince Real Estate (Cambodia) Co.,Ltd',
#   'category': 'Villa',
#   'price': '$690,000',
#   'infos': '[<span class="label">Bedrooms: 6</span>, <span class="label">Bathrooms: 8</span>, <span class="label">Car spaces: 3</span>, <span class="label">Floor area: 340m²</span>, <span class="label">Land area: 200m²</span>, <span class="label">Facing: S</span>]'},
#  {'name': 'ONE 70 Phnom Penh',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$53,000',
#   'infos': '[<span class="label">Total units: 793</span>, <span class="label">Unit types: Condo, Studio</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 37 to 91m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">37m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">37m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">38m²</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': 'DAKA KUN REALTY: ផ្ទះវីឡាទំនើប ស្ថិតនៅកណ្ដាលក្រុងសៀមរាប លក់បន្ទាន់ / Modern Villa for Sale in Siem Reap',
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$1,000,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Land area: 1049m²</span>]'},
#  {'name': '5 Floors House for Sale in Toul Kork',
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$380,000',
#   'infos': '[<span class="label">Car spaces: 1</span>, <span class="label">Land area: 60m²</span>, <span class="label">Floor level: 5</span>, <span class="label">Facing: S/W</span>]'},
#  {'name': 'Time Square 306',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$100,425',
#   'infos': '[<span class="label">Total units: 350</span>, <span class="label">Unit types: Condo, Condo</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 50 to 1600m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1600m²</span>, <span class="label">950m²</span>, <span class="label">11</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1600m²</span>, <span class="label">950m²</span>, <span class="label">11</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">50m²</span>, <span class="label">14</span>]'},
#  {'name': 'J Tower 2 Condominium',
#   'location': 'Phnom Penh',
#   'category': None,
#   'price': '$181,000',
#   'infos': '[<span class="label">Total units: 228</span>, <span class="label">Unit types: Condo</span>, <span class="label">2</span>, <span class="label">Floor area: 65 to 91m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">65m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">91m²</span>]'},
#  {'name': 'Land for Sale in Siem Reap-Wat Bo',
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$950/m²',
#   'infos': '[<span class="label">Land area: 1590m²</span>]'},
#  {'name': 'Best-priced Two Bedroom unit for Sale in J Tower 2 (BKK1)',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$229,062',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 91m²</span>, <span class="label">Floor level: 32</span>, <span class="label">Facing: N/E</span>]'},
#  {'name': 'LZ Sea View Residences',
#   'location': 'LZ Sea View ResidencesFeaturedRental Return: 6.0% a year for 2 yearsFor saleReady to Move InCondo$72,352   Sihanoukville Victory Beach 500m, Sangkat Buon, Sihanoukville, Sihanoukville\ue948 Total units: 600Total units: 600\ue947 Unit types: Condo, Serviced Apartment, StudioUnit types: Condo, Serviced Apartment, Studio\ue920 Bedrooms: 1 to 21 to 2\ue94a Floor area: 64 to 68m²64 to 68m²\ue923 High Return Yield\ue923 High Appreciation ValueLZ Sea View Residences LtdLZ Sea View Residence | Studio$72,352\ue920 11\ue91f 11\ue94a 43m²43m²LZ Sea View Residence | One-Bedroom$107,641\ue920 11\ue91f 11\ue94a 64m²64m²LZ Sea View Residence | Two-Bedrooms$123,281\ue920 22\ue91f 22\ue94a 68m²68m²',
#   'category': 'Condo',
#   'price': '$72,352',
#   'infos': '[<span class="label">Total units: 600</span>, <span class="label">Unit types: Condo, Serviced Apartment, Studio</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 64 to 68m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">43m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">64m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">68m²</span>]'},
#  {'name': 'Star Bay',
#   'location': 'Star BayFeaturedFor saleReady to Move InCondo$73,000   Sangkat Buon, Sihanoukville, Sihanoukville\ue948 Total units: 1956Total units: 1956\ue947 Unit types: Condo, StudioUnit types: Condo, Studio\ue920 11\ue94a Floor area: 32 to 66m²32 to 66m²\ue923 High Return Yield\ue923 High Appreciation ValueStar BaySea View Condo for Sale in Sihanoukville Star Bay project: Type A3 (Studio) $72,895$2,268/m²\ue920 11\ue91f 11\ue94a 33m²33m²Best Sea View Condo for sale in Sihanoukville Project Star Bay: Type A7 (1 Bedroom) $139,235$2,093/m²\ue920 11\ue91f 11\ue94a 66m²66m²Best Sea View Condo for sale in Sihanoukville Project Star Bay: Type A1 (1 Bedroom) $157,758$2,939/m²\ue920 11\ue91f 11\ue94a 54m²54m²',
#   'category': 'Condo',
#   'price': '$73,000',
#   'infos': '[<span class="label">Total units: 1956</span>, <span class="label">Unit types: Condo, Studio</span>, <span class="label">1</span>, <span class="label">Floor area: 32 to 66m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">33m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">66m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">54m²</span>]'},
#  {'name': 'Project Japanese Style House for Sale in Road No.3 area',
#   'location': 'Kampong Speu',
#   'category': 'Link House',
#   'price': '$38,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 67m²</span>, <span class="label">Land area: 84m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': 'Silvertown Metropolitan',
#   'location': 'Phnom Penh',
#   'category': None,
#   'price': '$183,151',
#   'infos': '[<span class="label">Total units: 111</span>, <span class="label">Unit types: Apartment, Condo, Serviced Apartment, Studio, Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 37 to 197m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">92m²</span>, <span class="label">3</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">92m²</span>, <span class="label">6</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">92m²</span>, <span class="label">7</span>]'},
#  {'name': 'New Borey Project Prince One Tropica | Link Villa for Sale in Sen Sok Area',
#   'location': 'New Borey Project Prince One Tropica | Link Villa for Sale in Sen Sok AreaFeaturedFor saleLuxury PropertyHouse$185,000  Prince One Tropica\ue920 Bedrooms: 44\ue91f Bathrooms: 55\ue90d Car spaces: 22\ue94a Floor area: 143m²143m²\ue93f Land area: 76m²76m²\ue923 High Return Yield\ue923 Brand Developer\ue923 High Appreciation Value Updated: 1\xa0week agoMLS Property Cambodia',
#   'category': 'House',
#   'price': '$185,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 2</span>, <span class="label">Floor area: 143m²</span>, <span class="label">Land area: 76m²</span>]'},
#  {'name': 'Prince One Tropica',
#   'location': 'Phnom Penh',
#   'category': 'Borey',
#   'price': '$185,000',
#   'infos': '[<span class="label">Total units: 426</span>, <span class="label">Unit types: House, Shophouse, Twin Villa, Villa</span>, <span class="label">Bedrooms: 4 to 7</span>, <span class="label">Floor area: 143 to 624m²</span>, <span class="label">4</span>, <span class="label">5</span>, <span class="label">2</span>, <span class="label">143m²</span>, <span class="label">76m²</span>, <span class="label">4</span>, <span class="label">5</span>, <span class="label">2</span>, <span class="label">189m²</span>, <span class="label">105m²</span>, <span class="label">4</span>, <span class="label">6</span>, <span class="label">2</span>, <span class="label">221m²</span>, <span class="label">105m²</span>, <span class="label">S</span>]'},
#  {'name': 'Samraong Village',
#   'location': 'Phnom Penh',
#   'category': 'Borey',
#   'price': '$203,600',
#   'infos': '[<span class="label">Unit types: Shophouse, Twin Villa, Link House, Villa</span>, <span class="label">Bedrooms: 3 to 6</span>, <span class="label">Floor area: 50 to 87m²</span>, <span class="label">6</span>, <span class="label">6</span>, <span class="label">2</span>, <span class="label">91m²</span>, <span class="label">176m²</span>, <span class="label">4</span>, <span class="label">5</span>, <span class="label">2</span>, <span class="label">72m²</span>, <span class="label">132m²</span>, <span class="label">3</span>, <span class="label">3</span>, <span class="label">1</span>, <span class="label">50m²</span>, <span class="label">90m²</span>]'},
#  {'name': 'ដីលក់បន្ទាន់\u200bប្លង់រឹងជាប់ផ្លូវជាតិលេខ4 Land for sale urgently, next to National Road 4, 96 meters wide, 16KM from Sihanoukville',
#   'location': 'ដីលក់បន្ទាន់\u200bប្លង់រឹងជាប់ផ្លូវជាតិលេខ4 Land for sale urgently, next to National Road 4, 96 meters wide, 16KM from SihanoukvilleFeaturedFor saleLand$2,777,830   ភូមិអូរតាសេក , Ou Oknha Heng, Prey Nob, Sihanoukville\ue93f Land area: 50506m²50506m² Updated: 10\xa0months ago',
#   'category': 'Land',
#   'price': '$2,777,830',
#   'infos': '[<span class="label">Land area: 50506m²</span>]'},
#  {'name': 'L Residence Borei Keila',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$51,213',
#   'infos': '[<span class="label">Unit types: Condo</span>, <span class="label">Floors: 32</span>, <span class="label">Completion Year: 2022</span>, <span class="label">34m²</span>, <span class="label">35m²</span>, <span class="label">60m²</span>]'},
#  {'name': 'Phnom Penh Galaxy Garden',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$73,000',
#   'infos': '[<span class="label">Total units: 1140</span>, <span class="label">Unit types: Condo, Condo</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 48 to 93m²</span>, <span class="label">47m²</span>, <span class="label">N</span>, <span class="label">47m²</span>, <span class="label">N</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">48m²</span>, <span class="label">6</span>]'},
#  {'name': 'Prince Happiness Plaza',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$80,718',
#   'infos': '[<span class="label">Total units: 1796</span>, <span class="label">Unit types: Condo, Land, Condo</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 32 to 96m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">52m²</span>, <span class="label">18</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">40m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">36m²</span>]'},
#  {'name': 'Vue Aston',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$65,000',
#   'infos': '[<span class="label">Total units: 895</span>, <span class="label">Unit types: Apartment, Condo, Condo</span>, <span class="label">Bedrooms: 1 to 4</span>, <span class="label">Floor area: 32 to 239m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">45m²</span>, <span class="label">6</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">33m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>]'},
#  {'name': 'Garden One',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$90,000',
#   'infos': '[<span class="label">Total units: 271</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 44 to 139m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">44m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">44m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">48m²</span>]'},
#  {'name': 'R&F CITY MIRO',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$86,013',
#   'infos': '[<span class="label">Total units: 612</span>, <span class="label">Unit types: Condo</span>, <span class="label">1</span>, <span class="label">Floor area: 38 to 39m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">38m²</span>, <span class="label">W</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">38m²</span>, <span class="label">10</span>, <span class="label">W</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">50m²</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': 'The Sky Park',
#   'location': 'Siem Reap',
#   'category': 'Condo',
#   'price': '$77,000',
#   'infos': '[<span class="label">Total units: 40</span>, <span class="label">Unit types: Condo, Land</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 72 to 138m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">72m²</span>, <span class="label">1</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">98m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">98m²</span>, <span class="label">1</span>]'},
#  {'name': 'Agile Sky Residence',
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$106,766',
#   'infos': '[<span class="label">Total units: 963</span>, <span class="label">Unit types: Apartment, Condo, Land, Apartment, Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 40 to 111m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">42m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">40m²</span>, <span class="label">4220m²</span>, <span class="label">42</span>, <span class="label">E/S</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">57m²</span>]'},
#  {'name': 'Suitable house and land in Takhmao city',
#   'location': 'Kandal',
#   'category': 'Land',
#   'price': '$149,999',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 2</span>, <span class="label">Floor area: 408m²</span>, <span class="label">Land area: 408m²</span>]'},
#  {'name': 'The Garden Residency II',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$63,500',
#   'infos': '[<span class="label">Total units: 369</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 30 to 70m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">30m²</span>, <span class="label">W</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">30m²</span>, <span class="label">E</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">38m²</span>, <span class="label">N</span>]'},
#  {'name': 'Wealth Mansion',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$111,500',
#   'infos': '[<span class="label">Total units: 1184</span>, <span class="label">Unit types: Apartment, Condo, Studio</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 55 to 128m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">64m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">63m²</span>, <span class="label">N</span>, <span class="label">2</span>, <span class="label">1</span>, <span class="label">67m²</span>, <span class="label">S</span>]'},
#  {'name': 'Chbar Ampov | Urgent Land for Sale',
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$2,990,000',
#   'infos': '[]'},
#  {'name': 'Le Condé BKK1 | Studio Room Type A3',
#   'location': 'Le Condé BKK1 | Studio Room Type A3FeaturedRental Return: 8.0% a year for 3 yearsFor saleLuxury PropertyStudio$139,895  Le Condé BKK1\ue920 Bedrooms: 11\ue91f Bathrooms: 11\ue94a Floor area: 39m²39m²\ue94b Floor level: 77\ue933 Facing: NN\ue923 High Return Yield\ue923 Brand Developer\ue923 High Appreciation Value\ue923 Promotional Discount Updated: 3\xa0days agoMLS Property Cambodia',
#   'category': 'Studio',
#   'price': '$139,895',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 39m²</span>, <span class="label">Floor level: 7</span>, <span class="label">Facing: N</span>]'},
#  {'name': 'Urban Village Phase 2',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$82,000',
#   'infos': '[<span class="label">Total units: 1700</span>, <span class="label">Unit types: Apartment, Condo, Studio, Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 29 to 90m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">29m²</span>, <span class="label">38m²</span>, <span class="label">28</span>, <span class="label">S/W</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">29m²</span>, <span class="label">38m²</span>, <span class="label">53</span>, <span class="label">S/W</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">67m²</span>, <span class="label">80m²</span>, <span class="label">23</span>, <span class="label">S/W</span>]'},
#  {'name': 'Royal Skyland',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$62,000',
#   'infos': '[<span class="label">Total units: 1440</span>, <span class="label">Unit types: Condo, Apartment, Condo</span>, <span class="label">Bedrooms: 1 to 5</span>, <span class="label">Floor area: 52 to 179m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">52m²</span>]'},
#  {'name': 'Royal Platinum Condominium',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$121,171',
#   'infos': '[<span class="label">Total units: 851</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 49 to 134m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">50m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">69m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">115m²</span>]'},
#  {'name': 'The Seven Residence Condominium',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$49,000',
#   'infos': '[<span class="label">Total units: 300</span>, <span class="label">Unit types: Condo</span>, <span class="label">1</span>, <span class="label">Floor area: 53 to 378m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">54m²</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">85m²</span>, <span class="label">7</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">378m²</span>, <span class="label">25</span>]'},
#  {'name': 'Romduol City',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$77,782',
#   'infos': '[<span class="label">Total units: 1129</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 2</span>, <span class="label">Floor area: 43 to 348m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">36m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">36m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">42m²</span>]'},
#  {'name': 'Prince International Plaza',
#   'location': 'Phnom Penh',
#   'category': 'Project',
#   'price': '$110,044',
#   'infos': '[<span class="label">Total units: 456</span>, <span class="label">Unit types: Condo</span>, <span class="label">Bedrooms: 1 to 3</span>, <span class="label">Floor area: 50 to 157m²</span>, <span class="label">1</span>, <span class="label">1</span>, <span class="label">50m²</span>, <span class="label">N</span>, <span class="label">2</span>, <span class="label">2</span>, <span class="label">81m²</span>, <span class="label">N</span>, <span class="label">2</span>, <span class="label">1</span>, <span class="label">94m²</span>, <span class="label">N</span>]'},
#  {'name': 'Orkidē Villa | The Botanic City',
#   'location': 'Phnom Penh',
#   'category': 'Borey',
#   'price': '$225,888',
#   'infos': '[<span class="label">Unit types: Twin Villa, Shophouse, Twin Villa, Link House, Villa</span>, <span class="label">Bedrooms: 3 to 5</span>, <span class="label">Floor area: 45 to 156m²</span>, <span class="label">3</span>, <span class="label">3</span>, <span class="label">2</span>, <span class="label">60m²</span>, <span class="label">96m²</span>, <span class="label">4</span>, <span class="label">5</span>, <span class="label">2</span>, <span class="label">75m²</span>, <span class="label">126m²</span>, <span class="label">3</span>, <span class="label">4</span>, <span class="label">2</span>, <span class="label">45m²</span>, <span class="label">128m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$1,162,300',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$2,200,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 5</span>, <span class="label">Floor area: 432m²</span>, <span class="label">Land area: 789m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': None,
#   'location': 'Kep',
#   'category': 'Land',
#   'price': '$780,000',
#   'infos': '[<span class="label">Land area: 8275m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Flat',
#   'price': '$250,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$300,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 184m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$145,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$80,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 43m²</span>, <span class="label">Floor level: 9</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$350,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$140,000',
#   'infos': '[<span class="label">Land area: 432m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$550,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Condo',
#   'price': '$75,647',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 47m²</span>, <span class="label">Floor level: 1</span>, <span class="label">Facing: N</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Condo',
#   'price': '$105,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 112m²</span>, <span class="label">Floor level: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Apartment',
#   'price': '$240,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 144m²</span>, <span class="label">Facing: W</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$220,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 122m²</span>, <span class="label">Floor level: 9</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$655,000',
#   'infos': '[<span class="label">Land area: 960m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$2,250,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 775m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$1,700,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$1,500,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$75,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 2</span>, <span class="label">Facing: N</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$58,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 76m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$88,283',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 56m²</span>, <span class="label">Floor level: 31</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$120,000',
#   'infos': '[<span class="label">Land area: 171m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$1,100,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Land area: 315m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$1,700,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Land area: 363m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$38,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$150,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$450,450',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$254,900',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 4</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 160m²</span>, <span class="label">Land area: 495m²</span>, <span class="label">Facing: N</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$650,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 2</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$397,800',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$65,440',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$104,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Flat House',
#   'price': '$170,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Flat House',
#   'price': '$165,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Flat House',
#   'price': '$475,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$297,500',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$450,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 2</span>, <span class="label">Floor area: 72m²</span>, <span class="label">Land area: 160m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$400,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 2</span>, <span class="label">Floor area: 72m²</span>, <span class="label">Land area: 160m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$190,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$65,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$131,175',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$1,070,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 4</span>, <span class="label">Floor area: 175m²</span>, <span class="label">Land area: 233m²</span>, <span class="label">Floor level: 20</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$325,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$135,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$150,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 135m²</span>, <span class="label">Floor level: 4</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$545,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Floor area: 90m²</span>, <span class="label">Land area: 195m²</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Condo',
#   'price': '$60,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$170,408',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$134,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$178,377',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$6,934,500',
#   'infos': '[<span class="label">Bedrooms: 31</span>, <span class="label">Bathrooms: 40</span>, <span class="label">Car spaces: 15</span>, <span class="label">Land area: 3015m²</span>, <span class="label">Floor level: 3</span>, <span class="label">Facing: W</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$42,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$3,532,200',
#   'infos': '[<span class="label">Land area: 609m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$581,040',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$115,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$300,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 4</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$1,100,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 7</span>, <span class="label">Floor area: 144m²</span>, <span class="label">Land area: 320m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$49,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 23m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Apartment',
#   'price': '$980,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$120,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$557,900',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$233,840',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$600,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$2,200/m²',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$2,200/m²',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Svay Rieng',
#   'category': 'House',
#   'price': '$389,000',
#   'infos': '[<span class="label">Land area: 1362m²</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$180,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$300,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Floor area: 72m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$350,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 4</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$710,000',
#   'infos': '[<span class="label">Bedrooms: 6</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Floor area: 168m²</span>, <span class="label">Land area: 368m²</span>, <span class="label">Facing: S</span>]'},
#  {'name': None,
#   'location': 'Kandal',
#   'category': 'Apartment',
#   'price': '$159,500',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 128m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$383,670',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$293,700',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Floor area: 72m²</span>, <span class="label">Land area: 169m²</span>, <span class="label">Facing: S</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$700,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$140,000',
#   'infos': '[<span class="label">Floor area: 62m²</span>, <span class="label">Floor level: 7</span>, <span class="label">Facing: W/N</span>]'},
#  {'name': None,
#   'location': 'Kandal',
#   'category': 'Link House',
#   'price': '$65,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$114,550',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$130,350',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Shophouse',
#   'price': '$390,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Shophouse',
#   'price': '$580,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$380,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 4</span>, <span class="label">Floor area: 216m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$94,739',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$145,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 90m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$290,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 187m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$295/m²',
#   'infos': '[<span class="label">Land area: 3200m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$783,900',
#   'infos': '[]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$1,560,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$135,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
# ...
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$160,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Land area: 200m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$53,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 6</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$105,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 6</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$75,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 13</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$140,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Land area: 64m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Link House',
#   'price': '$330,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Land area: 83m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$65,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 7</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$2,100,000',
#   'infos': '[<span class="label">Bedrooms: 6</span>, <span class="label">Bathrooms: 7</span>, <span class="label">Land area: 789m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Shophouse',
#   'price': '$175,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$95,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 20</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$3,500,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 5</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$100,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 11</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$125,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 138m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$230,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 176m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$150,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 150m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$160,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 68m²</span>, <span class="label">Land area: 89m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$50,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 40m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$66,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 49m²</span>, <span class="label">Floor level: 5</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$55,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 31m²</span>, <span class="label">Floor level: 11</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$450,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 4</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor area: 201m²</span>, <span class="label">Land area: 201m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$35,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor level: 7</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Condo',
#   'price': '$328,100',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 136m²</span>, <span class="label">Land area: 6000m²</span>, <span class="label">Floor level: 6</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$360,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Floor area: 647m²</span>, <span class="label">Land area: 652m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$240,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 10</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$99,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 16</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$78,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 14</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$35,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor level: 6</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$52,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 12</span>]'},
#  {'name': None,
#   'location': 'Kandal',
#   'category': 'Land',
#   'price': '$16,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$135,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 10</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$54,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor level: 13</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$119,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 8</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$250,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 2</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Twin Villa',
#   'price': '$320,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>, <span class="label">Car spaces: 2</span>, <span class="label">Land area: 157m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$550,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Land area: 1177m²</span>, <span class="label">Floor level: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$230,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 192m²</span>, <span class="label">Land area: 96m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$108,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 57m²</span>, <span class="label">Land area: 57m²</span>, <span class="label">Floor level: 9</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$239,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 115m²</span>, <span class="label">Floor level: 15</span>, <span class="label">Facing: N/E</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$1,100,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Floor area: 113m²</span>, <span class="label">Land area: 247m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Flat',
#   'price': '$340,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Floor area: 152m²</span>, <span class="label">Land area: 136m²</span>, <span class="label">Floor level: 3</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$296,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 4</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$79,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 46m²</span>, <span class="label">Land area: 46m²</span>, <span class="label">Floor level: 14</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$230,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 126m²</span>, <span class="label">Land area: 126m²</span>, <span class="label">Floor level: 15</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'House',
#   'price': '$1,500,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 2</span>, <span class="label">Floor area: 422m²</span>, <span class="label">Land area: 422m²</span>, <span class="label">Floor level: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$295,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Floor area: 186m²</span>, <span class="label">Floor level: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Apartment',
#   'price': '$180,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 55m²</span>, <span class="label">Floor level: 19</span>, <span class="label">Facing: E</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$5,700,000',
#   'infos': '[<span class="label">Bedrooms: 8</span>, <span class="label">Bathrooms: 11</span>, <span class="label">Car spaces: 3</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$1,500,000',
#   'infos': '[<span class="label">Bedrooms: 5</span>, <span class="label">Bathrooms: 6</span>, <span class="label">Car spaces: 7</span>, <span class="label">Land area: 643m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$85,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 39</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$85,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Car spaces: 1</span>, <span class="label">Floor level: 39</span>]'},
#  {'name': None,
#   'location': None,
#   'category': None,
#   'price': None,
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$128,135',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 52m²</span>, <span class="label">Land area: 52m²</span>, <span class="label">Floor level: 2</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Condo',
#   'price': '$125,000',
#   'infos': '[<span class="label">Bedrooms: 1</span>, <span class="label">Bathrooms: 1</span>, <span class="label">Floor area: 56m²</span>, <span class="label">Land area: 56m²</span>, <span class="label">Floor level: 7</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Land',
#   'price': '$59,150',
#   'infos': '[<span class="label">Land area: 455m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Villa',
#   'price': '$270,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 3</span>, <span class="label">Land area: 240m²</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'Flat',
#   'price': '$330,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 5</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$260,000',
#   'infos': '[<span class="label">Bedrooms: 3</span>, <span class="label">Bathrooms: 3</span>]'},
#  {'name': None,
#   'location': 'Siem Reap',
#   'category': 'House',
#   'price': '$140,000',
#   'infos': '[<span class="label">Bedrooms: 2</span>, <span class="label">Bathrooms: 1</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$300,000',
#   'infos': '[<span class="label">Land area: 1218m²</span>]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Land',
#   'price': '$165,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$105,000',
#   'infos': '[<span class="label">Floor level: 2</span>]'},
#  {'name': None,
#   'location': 'Kandal',
#   'category': 'Land',
#   'price': '$36,500,000',
#   'infos': '[]'},
#  {'name': None,
#   'location': 'Phnom Penh',
#   'category': 'Villa',
#   'price': '$470,000',
#   'infos': '[<span class="label">Bedrooms: 4</span>, <span class="label">Bathrooms: 4</span>, <span class="label">Land area: 446m²</span>, <span class="label">Floor level: 1</span>]'},
#  ...]
